# %%
#Scrape packages
from bs4 import BeautifulSoup
import selenium
import pandas as pd
from selenium import webdriver

import requests
import time
import re

import scraping_class
logfile = 'log.csv'## name your log file.
connector = scraping_class.Connector(logfile)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

wiki_url='https://en.wikipedia.org/wiki/List_of_current_members_of_the_United_States_House_of_Representatives'
table_id= 'votingmembers'
response = requests.get(wiki_url)
soup=BeautifulSoup(response.text,'html.parser')
congress_table=soup.find('table', attrs={'id' : table_id})
df=pd.read_html(str(congress_table))
df
# Out:
# [             District             Member  Party     Party.1  \
#  0           Alabama 1      Bradley Byrne    NaN  Republican
#  1           Alabama 2        Martha Roby    NaN  Republican
#  2           Alabama 3        Mike Rogers    NaN  Republican
#  3           Alabama 4    Robert Aderholt    NaN  Republican
#  4           Alabama 5          Mo Brooks    NaN  Republican
#  ..                ...                ...    ...         ...
#  430       Wisconsin 5  Jim Sensenbrenner    NaN  Republican
#  431       Wisconsin 6     Glenn Grothman    NaN  Republican
#  432       Wisconsin 7        Tom Tiffany    NaN  Republican
#  433       Wisconsin 8     Mike Gallagher    NaN  Republican
#  434  Wyoming at-large         Liz Cheney    NaN  Republican
#
#                                        Prior experience  \
#  0       Alabama SenateAlabama State Board of Education
#  1                     Montgomery, Alabama City Council
#  2    Calhoun County, Alabama CommissionerAlabama Ho...
#  3                  Haleyville, Alabama Municipal Judge
#  4    Alabama House of RepresentativesMadison County...
#  ..                                                 ...
#  430     Wisconsin State SenateWisconsin State Assembly
#  431           Wisconsin SenateWisconsin State Assembly
#  432           Wisconsin SenateWisconsin State Assembly
#  433                 Political advisorU.S. Marine Corps
#  434  Principal Deputy Assistant Secretary of State ...
#
#                                               Education  Assumed office  \
#  0       Duke University (BA)University of Alabama (JD)  2014 (special)
#  1      New York University (BM)Samford University (JD)            2011
#  2    Jacksonville State University (BA, MPA)Birming...            2003
#  3    University of North AlabamaBirmingham–Southern...            1997
#  4       Duke University (BA)University of Alabama (JD)            2011
#  ..                                                 ...             ...
#  430  Stanford University (BA)University of Wisconsi...            1979
#  431           University of Wisconsin–Madison (BA, JD)            2015
#  432           University of Wisconsin–River Falls (BS)  2020 (special)
#  433  Princeton University (BA)National Intelligence...            2017
#  434    Colorado College (BA)University of Chicago (JD)            2017
#
#             Residence    Born
#  0           Fairhope  1955.0
#  1         Montgomery  1976.0
#  2               Saks  1958.0
#  3         Haleyville  1965.0
#  4         Huntsville  1954.0
#  ..               ...     ...
#  430  Menomonee Falls  1943.0
#  431    Campbellsport  1955.0
#  432         Minocqua  1957.0
#  433        Green Bay  1984.0
#  434          Jackson  1966.0
#
#  [435 rows x 9 columns]]

# %%
#WIKI
corona_url = 'https://en.wikipedia.org/wiki/Template:COVID-19_pandemic_data'
table_id2 ='thetable'
response2 = requests.get(corona_url)
soup2 = BeautifulSoup(response2.text,'html.parser')
corona_table = soup2.find('table', attrs={'id': table_id2})
df2=pd.read_html(str(corona_table))
df2

df2[0]
# Out:
#                                            Location[a]  \
#                                     Unnamed: 0_level_1
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 226                                                NaN
# 227                                                NaN
# 228                                                NaN
# 229  As of 20 August 2020 (UTC) · History of cases ...
# 230  Notes ^ Location: Countries, territories, and ...
#
#                                                         \
#                                               World[e]
# 0                                     United States[f]
# 1                                            Brazil[g]
# 2                                                India
# 3                                            Russia[h]
# 4                                         South Africa
# ..                                                 ...
# 226                                           Anguilla
# 227                                     Sint Eustatius
# 228                                       Tanzania[bd]
# 229  As of 20 August 2020 (UTC) · History of cases ...
# 230  Notes ^ Location: Countries, territories, and ...
#
#                                               Cases[b]  \
#                                             22,427,054
# 0                                              5605858
# 1                                              3460413
# 2                                              2836925
# 3                                               942106
# 4                                               596060
# ..                                                 ...
# 226                                                  3
# 227                                                  2
# 228                                            No data
# 229  As of 20 August 2020 (UTC) · History of cases ...
# 230  Notes ^ Location: Countries, territories, and ...
#
#                                              Deaths[c]  \
#                                                788,015
# 0                                               174963
# 1                                               111189
# 2                                                53866
# 3                                                16099
# 4                                                12423
# ..                                                 ...
# 226                                                  0
# 227                                                  0
# 228                                            No data
# 229  As of 20 August 2020 (UTC) · History of cases ...
# 230  Notes ^ Location: Countries, territories, and ...
#
#                                              Recov.[d]  \
#                                             14,349,473
# 0                                              2852221
# 1                                              2615254
# 2                                              2096664
# 3                                               755513
# 4                                               491441
# ..                                                 ...
# 226                                                  3
# 227                                                  2
# 228                                            No data
# 229  As of 20 August 2020 (UTC) · History of cases ...
# 230  Notes ^ Location: Countries, territories, and ...
#
#                                                   Ref.
#                                                    [2]
# 0                                                  [9]
# 1                                             [13][14]
# 2                                                 [15]
# 3                                                 [16]
# 4                                                 [17]
# ..                                                 ...
# 226                                              [315]
# 227                                              [316]
# 228                                         [318][319]
# 229  As of 20 August 2020 (UTC) · History of cases ...
# 230  Notes ^ Location: Countries, territories, and ...
#
# [231 rows x 6 columns]

# %%
#Wiki
url = f'https://en.wikipedia.org/wiki/Template:COVID-19_pandemic_data'
table_id='thetable'
response = requests.get(url)
soup = BeautifulSoup(response.text,'html.parser')
corona = soup.find('table2', attrs={'id': table_id})
df=pd.read_html(str(table2))
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-be02c7357dca> in <module>
#       5 soup = BeautifulSoup(response.text,'html.parser')
#       6 corona = soup.find('table2', attrs={'id': table_id})
# ----> 7 df=pd.read_html(str(table2))
#       8 df
#
# NameError: name 'table2' is not defined

# %%
#SSI
url = f'https://www.sst.dk/da/corona/tal-og-overvaagning'
response = connector.get(url,'review_getter')
html = response[0].text
soup = BeautifulSoup(html,'html.parser')
score_text_elem = soup.find_all(class_ ='table-responsive')
#score = re.search("\d+\.\d+",score_text_elem.text).group()
score_text_elem
#html

soup.find()
# Out:
# <html lang="da" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <style>
#
#         .o-header .o-shortcuts.nav {
#             opacity: 0;
#             transform: translateY(-100%);
#         }
#     </style>
# <link href="/dist/images/favicons/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/dist/images/favicons/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/dist/images/favicons/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/dist/images/favicons/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/dist/images/favicons/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/dist/images/favicons/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/dist/images/favicons/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/dist/images/favicons/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/dist/images/favicons/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/dist/images/favicons/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/dist/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/dist/images/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/dist/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/dist/images/favicons/manifest.json" rel="manifest"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/dist/images/favicons/ms-icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <title>Tal og overvågning over coronavirus/COVID-19 - Sundhedsstyrelsen</title>
# <meta content="Samlet data over coronavirus/COVIDS-19 i form af grafer og tabeller. Siden opdateres dagligt." name="description">
# <meta content="" name="keywords">
# <meta content="INDEX,FOLLOW" name="robots">
# <meta content="20-08-2020 11:48:25" name="last-updated"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, shrink-to-fit=no" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="telephone=no" name="format-detection">
# <link href="https://www.sst.dk/da/corona/tal-og-overvaagning" rel="canonical">
# <meta content="Tal og overvågning af COVID-19" property="og:title">
# <meta content="Her samler vi data om coronavirus/COVID-19. Der vises data om testede, smittede, personer med overstået infektion, indlagte patienter og dødsfald." property="og:description"/>
# <meta content="article" property="og:type">
# <meta content="https://www.sst.dk/da/corona/tal-og-overvaagning" property="og:url"/>
# <meta content="https://www.sst.dk/-/media/images/pentia/sst-logo.ashx" property="og:image">
# <meta content="584" property="og:image:width">
# <meta content="304" property="og:image:height"/>
# <meta content="Coronavirus" property="search:subject"/>
# <meta content="Coronavirus" property="search:subject"/>
# <meta content="Smitsomme sygdomme" property="search:subject"/>
# <meta content="Beredskab" property="search:subject"/>
# <meta content="Indholdsside" property="search:documenttype"/>
# <link href="/dist/css/style-6f15d726f4.css" rel="stylesheet" sri="sha256-5H8rIU2F04KuWSlt7TFOVob45wTj9veTMUj05Qs/CtU= sha384-+v+YXQ03rIhRKzwnwuc/RsZrXeH2zzF0kvYwQ2q8e1QitTg8IweePf51vIYWjnEv sha512-2UnP8terdvj0QsArADR6lnO0jiPpV+NskaKPiE4W9QOJb8C7XBbwcSYvY/TFJA64otak+v5zBZSNFWTx8w6w+w==">
# <script data-cbid="0a3de6f0-a6b5-4e4b-bb66-23a16ba4bba9" id="Cookiebot" src="https://consent.cookiebot.com/uc.js" type="text/javascript"></script>
# </link></meta></meta></meta></meta></link></meta></meta></meta></meta></head>
# <body class="u-site" data-env="ReleaseCd">
# <div class="a-sprite">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><symbol id="Arrow_left_icon" viewbox="0 0 5 9" xmlns="http://www.w3.org/2000/svg"><path d="M4.408 1.002L1.002 4.408l3.406 3.405" fill="none"></path></symbol><symbol id="Arrow_right_icon" viewbox="0 0 6 9" xmlns="http://www.w3.org/2000/svg"><path d="M1.408 1.003l3.405 3.405-3.405 3.406" fill="none"></path></symbol><symbol id="Burger_Icon" viewbox="0 0 30 14" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h30v2H0zm0 6h30v2H0zm0 6h30v2H0z" fill-rule="evenodd"></path></symbol><symbol id="Date_icon" viewbox="0 0 14 14" xmlns="http://www.w3.org/2000/sv
z" transform="translate(-206.79 -231.68)"></path>
# <path class="a" d="M604,340.09a24.47,24.47,0,0,1-9.14-1.76l1-4.35a27.5,27.5,0,0,0,8.27,1.36c4,0,4.66-.83,4.66-3.65,0-3.25-.09-3.51-5.36-4.66-7.08-1.58-8-2.94-8-9.14,0-5.32,2.42-8,9.85-8a39.93,39.93,0,0,1,8.53,1l-.62,4.66a38.16,38.16,0,0,0-7.82-.88c-3.74,0-4.4.79-4.4,3.34,0,3.34.09,3.43,5.14,4.66,7.88,1.89,8.27,3.17,8.27,9C614.28,337.24,612.65,340.09,604,340.09Z" transform="translate(-206.79 -231.68)"></path>
# <path class="a" d="M621.1,310.37H639v4.88h-12.4v7.08h11.43v4.88H626.64v7.56H639v4.88H621.1Z" transform="translate(-206.79 -231.68)"></path>
# <path class="a" d="M651.49,317.45v22.2h-5.41V310.37h7.39l11.12,22.25V310.37H670v29.28h-7.39Z" transform="translate(-206.79 -231.68)"></path>
# </svg>
# </a>
# </div>
# <div class="u-grid__cell u-grid__cell--right o-header__padding-right">
# <div class="u-grid u-grid--no-gutter o-header__toolbar">
# <div class="u-grid__cell o-header__language">
# <a class="a-link o-header__language-link" href="/en/English" title="English">English</a>
# <div class="o-shortcuts o-shortcuts--light-bg" data-behavior="shortcuts" data-instance="shortcuts__MJ74GQ">
# <label class="o-shortcuts__label" for="shortcuts__checkbox">
# <input class="o-shortcuts__checkbox" data-ref="shortcuts__checkbox" id="shortcuts__checkbox" type="checkbox"/>
# <div class="m-link-icon o-shortcuts__link m-link-icon--reverted" data-ref="shortcuts__toggle" title="Genveje">
# <span class="a-icon m-link-icon__icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Icon_Function_ChevronDown" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span class="m-link-icon__label">Genveje</span>
# </div>
# <nav class="o-shortcuts__nav" role="navigation">
# <div class="o-shortcuts__nav-container u-site-container" data-ref="shortcuts__navContainer">
# <div class="o-shortcuts__header">Genveje</div>
# </div>
# </nav>
# </label>
# </div>
# </div>
# <div class="u-grid__cell o-header__search">
# <div class="o-search" data-behavior="search" data-instance="search__KEE328">
# <label class="o-search__open" data-ref="search__open" for="search-active-checkbox">
# <span class="a-icon o-search__icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Icon_Nav_Search" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <input autocomplete="off" class="o-search__checkbox" data-ref="search__checkbox" id="search-active-checkbox" type="checkbox" value=""/>
# <form autocomplete="off" class="o-search__panel" id="cludo-nav-search">
# <label class="sr-only" for="search-input">Indtast søgeord</label>
# <input class="o-search__panel-input" data-ref="search__input" id="search-input" name="search" placeholder="Indtast søgeord" type="text"/>
# <button class="m-link-icon m-link-icon--button m-link-icon--button-disabled" data-ref="search__button" type="submit">
# <span class="a-icon m-link-icon__icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Icon_Nav_Search" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span class="m-link-icon__label">Søg</span>
# </button>
# <label class="o-search__close" data-ref="search__close" for="search-active-checkbox">
# <span class="a-icon o-search__icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Icon_Nav_Close" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# </form>
# </div>
# <div>
# <div class="o-off-canvas" data-behavior="off-canvas" data-instance="off-canvas__JXZR3Z">
# <a class="m-burger-link" data-ref="off-canvas__open" href="#" title="Menu">
# <svg class="m-burger-link__asset">
# <use xlink:href="#Burger_Icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# <div class="o-off-canvas__mask" data-ref="off-canvas__mask"></div>
# <nav class="o-off-canvas__plate" data-ref="off-canvas__plate">
# <div class="o-off-canvas__top">
# <a class="m-logo" href="/da" title="">
# <?xml version="1.0" encoding="utf-8"?>
# <svg class="m-logo__svg" viewbox="0 0 463.21 108.41" xmlns="http://www.w3.org/2000/svg">
# <defs></defs>
# <title>Sundhedsstyrelsen</title>
z" transform="translate(-206.79 -231.68)"></path>
# <path class="a" d="M471.09,315.25h-8.18v-4.88h21.9v4.88h-8.18v24.4h-5.54Z" transform="translate(-206.79 -231.68)"></path>
# <path class="a" d="M506.89,310.37h5.89l-9.45,20.8v8.48h-5.54v-8.48l-9.46-20.8h5.89l6.34,14.77Z" transform="translate(-206.79 -231.68)"></path>
# <path class="a" d="M535.17,339.65,528.44,330h-5.28v9.67h-5.54V310.37h12c6.82,0,9.33,2.77,9.33,7.91v3.83c0,3.52-1.32,6-4.4,7.08l7.26,10.46Zm-5.76-24.4h-6.25v9.94h6.25c3,0,4-1.1,4-3.57v-2.9C533.41,316.26,532.35,315.25,529.41,315.25Z" transform="translate(-206.79 -231.68)"></path>
# <path class="a" d="M547.53,310.37h17.94v4.88h-12.4v7.08H564.5v4.88H553.07v7.56h12.4v4.88H547.53Z" transform="translate(-206.79 -231.68)"></path>
# <path class="a" d="M578,334.77h12.05v4.88H572.5V310.37H578Z" transform="translate(-206.79 -231.68)"></path>
# <path class="a" d="M604,340.09a24.47,24.47,0,0,1-9.14-1.76l1-4.35a27.5,27.5,0,0,0,8.27,1.36c4,0,4.66-.83,4.66-3.65,0-3.25-.09-3.51-5.36-4.66-7.08-1.58-8-2.94-8-9.14,0-5.32,2.42-8,9.85-8a39.93,39.93,0,0,1,8.53,1l-.62,4.66a38.16,38.16,0,0,0-7.82-.88c-3.74,0-4.4.79-4.4,3.34,0,3.34.09,3.43,5.14,4.66,7.88,1.89,8.27,3.17,8.27,9C614.28,337.24,612.65,340.09,604,340.09Z" transform="translate(-206.79 -231.68)"></path>
# <path class="a" d="M621.1,310.37H639v4.88h-12.4v7.08h11.43v4.88H626.64v7.56H639v4.88H621.1Z" transform="translate(-206.79 -231.68)"></path>
# <path class="a" d="M651.49,317.45v22.2h-5.41V310.37h7.39l11.12,22.25V310.37H670v29.28h-7.39Z" transform="translate(-206.79 -231.68)"></path>
# </svg>
# </a>
# <div class="o-off-canvas__close" data-ref="off-canvas__close">
# <span class="a-icon o-off-canvas__close-icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Icon_Nav_Close" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </div>
# </div>
# <div class="o-off-canvas__container" data-ref="off-canvas__container">
# <div class="o-off-canvas__clusternav-container" data-ref="off-canvas__clusternav-container">
# <nav class="o-cluster-nav-mobile" data-behavior="clusternav-mobile" role="navigation">
# <ul data-context-url="/da/corona/tal-og-overvaagning" data-ref="o-cluster-nav-mobile__slider">
# <li class="o-cluster-nav-mobile__level-1 has-children">
# <a class="" href="/da/Viden">Viden<span></span></a>
# <ul class="js-isopen">
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
#                 Viden
#             </a>
# </li>
# <li class="has-children">
# <a class="" href="/da/Viden/Akut-sundhedsindsats">
# <span></span>
#                 Akut sundhedsindsats
#             </a>
# <ul class="">
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
#                 Akut sundhedsindsats
#             </a>
# </li>
# <li class="has-children">
# <a class="" href="/da/Viden/Akut-sundhedsindsats/Anbefalinger-til-den-akutte-sundhedsindsats">
# <span></span>
#                 Anbefalinger til den akutte sundhedsindsats
#             </a>
# <ul class="">
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Akut-sundhedsindsats">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
#                 Anbefalinger til den akutte sundhedsindsats
#             </a>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Akut-sundhedsindsats/Anbefalinger-til-den-akutte-sundhedsindsats/Gaeldende-anbefalinger">
# <span></span>
#                 Gældende anbefalinger
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Akut-sundhedsindsats/Anbefalinger-til-den-akutte-sundhedsindsats/Gaeldende-anbefalinger">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Gældende anbefalinger
#                 </a>
# </li>
# </ul>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Akut-sundhedsindsats/Anbefalinger-til-den-akutte-sundhedsindsats/Udarbejdelse-af-nye-anbefalinger">
# <span></span>
#                 Udarbejdelse af nye anbefalinger
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Akut-sundhedsindsats/Anbefalinger-til-den-akutte-sundhedsindsats/Udarbejdelse-af-nye-anbefalinger">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Udarbejdelse af nye anbefalinger
#                 </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="has-children">
# <a class="" href="/da/Viden/Alkohol">
# <span></span>
#                 Alkohol
#             </a>
# <ul class="">
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
#                 Alkohol
#             </a>
# </li>
# <li class="has-children">
# <a class="" href="/da/Viden/Alkohol/Fakta-om-alkohol">
# <span></span>
#                 Fakta om alkohol
#             </a>
# <ul class="">
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
#                 Fakta om alkohol
#             </a>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Alkohol/Fakta-om-alkohol/Noegletal-om-alkohol">
# <span></span>
#                 Nøgletal om alkohol
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol/Fakta-om-alkohol/Noegletal-om-alkohol">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Nøgletal om alkohol
#                 </a>
# </li>
# </ul>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Alkohol/Fakta-om-alkohol/Unges-alkoholforbrug">
# <span></span>
#                 Unges alkoholforbrug
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol/Fakta-om-alkohol/Unges-alkoholforbrug">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Unges alkoholforbrug
#                 </a>
# </li>
# </ul>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Alkohol/Fakta-om-alkohol/Alkohol-og-sygdomme">
# <span></span>
#                 Alkohol og sygdomme
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol/Fakta-om-alkohol/Alkohol-og-sygdomme">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Alkohol og sygdomme
#                 </a>
# </li>
# </ul>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Alkohol/Fakta-om-alkohol/Alkohol-og-graviditet">
# <span></span>
#                 Alkohol og graviditet
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol/Fakta-om-alkohol/Alkohol-og-graviditet">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Alkohol og graviditet
#                 </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="has-children">
# <a class="" href="/da/Viden/Alkohol/Alkoholforebyggelse">
# <span></span>
#                 Alkoholforebyggelse
#             </a>
# <ul class="">
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
#                 Alkoholforebyggelse
#             </a>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Alkohol/Alkoholforebyggelse/Sundhedsstyrelsens-udmeldinger-om-alkohol">
# <span></span>
#                 Sundhedsstyrelsens udmeldinger om alkohol
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol/Alkoholforebyggelse/Sundhedsstyrelsens-udmeldinger-om-alkohol">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Sundhedsstyrelsens udmeldinger om alkohol
#                 </a>
# </li>
# </ul>
# </li>
# <li class="has-children">
# <a class="" href="/da/Viden/Alkohol/Alkoholforebyggelse/Forebyggelsesindsats">
# <span></span>
#                 Forebyggelsesindsats
#             </a>
# <ul class="">
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol/Alkoholforebyggelse">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
#                 Forebyggelsesindsats
#             </a>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Alkohol/Alkoholforebyggelse/Forebyggelsesindsats/Forebyggelsespakke-om-alkohol">
# <span></span>
#                 Forebyggelsespakke om alkohol
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol/Alkoholforebyggelse/Forebyggelsesindsats/Forebyggelsespakke-om-alkohol">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Forebyggelsespakke om alkohol
#                 </a>
# </li>
# </ul>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Alkohol/Alkoholforebyggelse/Forebyggelsesindsats/Boern-og-unge">
# <span></span>
#                 Børn og unge
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol/Alkoholforebyggelse/Forebyggelsesindsats/Boern-og-unge">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Børn og unge
#                 </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="has-children">
# <a class="" href="/da/Viden/Alkohol/Alkoholbehandling">
# <span></span>
#                 Alkoholbehandling
#             </a>
# <ul class="">
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
#                 Alkoholbehandling
#             </a>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Alkohol/Alkoholbehandling/Opsporing-af-alkoholproblemer">
# <span></span>
#                 Opsporing af alkoholproblemer
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol/Alkoholbehandling/Opsporing-af-alkoholproblemer">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Opsporing af alkoholproblemer
#                 </a>
# </li>
# </ul>
# </li>
# <li class="has-children">
# <a class="" href="/da/Viden/Alkohol/Alkoholbehandling/Kvalitet-i-alkoholbehandling">
# <span></span>
#                 Kvalitet i alkoholbehandling
#             </a>
# <ul class="">
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol/Alkoholbehandling">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
#                 Kvalitet i alkoholbehandling
#             </a>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Alkohol/Alkoholbehandling/Kvalitet-i-alkoholbehandling/NKR-om-alkohol">
# <span></span>
#                 NKR om alkohol
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol/Alkoholbehandling/Kvalitet-i-alkoholbehandling/NKR-om-alkohol">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     NKR om alkohol
#                 </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Alkohol/Alkoholbehandling/Det-Nationale-Alkoholbehandlingsregister">
# <span></span>
#                 Det Nationale Alkoholbehandlingsregister
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol/Alkoholbehandling/Det-Nationale-Alkoholbehandlingsregister">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Det Nationale Alkoholbehandlingsregister
#                 </a>
# </li>
# </ul>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Alkohol/Alkoholbehandling/Godkendelse-af-behandlingssteder">
# <span></span>
#                 Godkendelse af behandlingssteder
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol/Alkoholbehandling/Godkendelse-af-behandlingssteder">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Godkendelse af behandlingssteder
#                 </a>
# </li>
# </ul>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Alkohol/Alkoholbehandling/Kommunale-omkostninger">
# <span></span>
#                 Kommunale omkostninger
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol/Alkoholbehandling/Kommunale-omkostninger">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Kommunale omkostninger
#                 </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="has-children">
# <a class="" href="/da/Viden/Alkohol/Boern-i-familier-med-alkoholproblemer">
# <span></span>
#                 Børn i familier med alkoholproblemer
#             </a>
# <ul class="">
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
#                 Børn i familier med alkoholproblemer
#             </a>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Alkohol/Boern-i-familier-med-alkoholproblemer/Stoette-til-boern">
# <span></span>
#                 Støtte til børn
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol/Boern-i-familier-med-alkoholproblemer/Stoette-til-boern">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Støtte til børn
#                 </a>
# </li>
# </ul>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Alkohol/Boern-i-familier-med-alkoholproblemer/Raadgivning-og-behandling">
# <span></span>
#                 Rådgivning og behandling
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol/Boern-i-familier-med-alkoholproblemer/Raadgivning-og-behandling">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Rådgivning og behandling
#                 </a>
# </li>
# </ul>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Alkohol/Boern-i-familier-med-alkoholproblemer/Raadgivning-til-fagpersoner">
# <span></span>
#                 Rådgivning til fagpersoner
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Alkohol/Boern-i-familier-med-alkoholproblemer/Raadgivning-til-fagpersoner">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Rådgivning til fagpersoner
#                 </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="has-children">
# <a class="" href="/da/Viden/Antibiotikaresistens">
# <span></span>
#                 Antibiotikaresistens
#             </a>
# <ul class="">
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
#                 Antibiotikaresistens
#             </a>
# </li>
# <li class="has-children">
# <a class="" href="/da/Viden/Antibiotikaresistens/Fakta-om-multiresistente-bakterier">
# <span></span>
#                 Fakta om multiresistente bakterier
#             </a>
# <ul class="">
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Antibiotikaresistens">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
#                 Fakta om multiresistente bakterier
#             </a>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Antibiotikaresistens/Fakta-om-multiresistente-bakterier/MRSA">
# <span></span>
#                 MRSA
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Antibiotikaresistens/Fakta-om-multiresistente-bakterier/MRSA">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     MRSA
#                 </a>
# </li>
# </ul>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Antibiotikaresistens/Fakta-om-multiresistente-bakterier/CPO">
# <span></span>
#                 CPO
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Antibiotikaresistens/Fakta-om-multiresistente-bakterier/CPO">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     CPO
#                 </a>
# </li>
# </ul>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Antibiotikaresistens/Fakta-om-multiresistente-bakterier/VRE">
# <span></span>
#                 VRE
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Antibiotikaresistens/Fakta-om-multiresistente-bakterier/VRE">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     VRE
#                 </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="has-children">
# <a class="" href="/da/Viden/Antibiotikaresistens/Forebyggelse-af-antibiotikaresistens">
# <span></span>
#                 Forebyggelse af antibiotikaresistens
#             </a>
# <ul class="">
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Antibiotikaresistens">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
#                 Forebyggelse af antibiotikaresistens
#             </a>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Antibiotikaresistens/Forebyggelse-af-antibiotikaresistens/Vejledning-til-laeger">
# <span></span>
#                 Vejledning til læger
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Antibiotikaresistens/Forebyggelse-af-antibiotikaresistens/Vejledning-til-laeger">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Vejledning til læger
#                 </a>
# </li>
# </ul>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Antibiotikaresistens/Forebyggelse-af-antibiotikaresistens/Information-til-borgere">
# <span></span>
#                 Information til borgere
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Antibiotikaresistens/Forebyggelse-af-antibiotikaresistens/Information-til-borgere">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Information til borgere
#                 </a>
# </li>
# </ul>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Antibiotikaresistens/Forebyggelse-af-antibiotikaresistens/Inspirationskatalog,-c-,-20-veje-til-at-bruge-mindre-antibiotika">
# <span></span>
#                 Inspirationskatalog: 20 veje til at bruge mindre antibiotika
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Antibiotikaresistens/Forebyggelse-af-antibiotikaresistens/Inspirationskatalog,-c-,-20-veje-til-at-bruge-mindre-antibiotika">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Inspirationskatalog: 20 veje til at bruge mindre antibiotika
#                 </a>
# </li>
# </ul>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Antibiotikaresistens/Forebyggelse-af-antibiotikaresistens/Antibiotikaellerej,-d-,dk">
# <span></span>
#                 Antibiotikaellerej.dk
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Antibiotikaresistens/Forebyggelse-af-antibiotikaresistens/Antibiotikaellerej,-d-,dk">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Antibiotikaellerej.dk
#                 </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Astma-og-allergi">
# <span></span>
#                 Astma og allergi
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Astma-og-allergi">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Astma og allergi
#                 </a>
# </li>
# </ul>
# </li>
# <li class="has-children">
# <a class="" href="/da/Viden/Beredskab">
# <span></span>
#                 Beredskab
#             </a>
# <ul class="">
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
#                 Beredskab
#             </a>
# </li>
# <li class="has-children">
# <a class="" href="/da/Viden/Beredskab/Sundhedsberedskabet">
# <span></span>
#                 Sundhedsberedskabet
#             </a>
# <ul class="">
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Beredskab">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
#                 Sundhedsberedskabet
#             </a>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Beredskab/Sundhedsberedskabet/Vejledning-til-kommuner-og-regioner">
# <span></span>
#                 Vejledning til kommuner og regioner
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Beredskab/Sundhedsberedskabet/Vejledning-til-kommuner-og-regioner">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Vejledning til kommuner og regioner
#                 </a>
# </li>
# </ul>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Beredskab/Sundhedsberedskabet/Psykosocial-indsats-ved-beredskabshaendelser">
# <span></span>
#                 Psykosocial indsats ved beredskabshændelser
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Beredskab/Sundhedsberedskabet/Psykosocial-indsats-ved-beredskabshaendelser">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# <svg class="a-icon__asset"><use xlink:href="#Arrow_left_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
#                     Psykosocial indsats ved beredskabshændelser
#                 </a>
# </li>
# </ul>
# </li>
# <li class="">
# <a class="" href="/da/Viden/Beredskab/Sundhedsberedskabet/Beredskab-for-graenseoverskridende-sundhedstrusler_-IHR">
# <span></span>
#                 Beredskab for grænseoverskridende sundhedstrusler, IHR
#             </a>
# <ul>
# <li>
# <a class="o-cluster-nav-mobile__back" href="/da/Viden/Beredskab/Sundhedsberedskabet/Beredskab-for-graenseoverskridende-sundhedstrusler_-IHR">
# <span class="a-icon o-cluster-nav-mobile__back-icon">
# ...
# <h3>5.1 Dødsfald: dødsdato - kumuleret</h3>
# <p>Dødsfald med COVID-19-infektion, fordelt på dødsdato - kumuleret</p>
# </div>
# <div class="o-content-block__content o-content-block__content--push-bottom">
# <a><img alt="Graf, der viser det kumulerede antal dødsfald med COVID-19-infektion fordelt på dødsdato. X-aksen viser dato, og Y-aksen viser kummuleret antal personer." height="480" src="/-/media/Udgivelser/2020/Corona/Overvågningsdata/Data-1808/fig_3_2.ashx?h=480&amp;la=da&amp;w=800&amp;hash=0D19B45A53EBC728336778E041F675536744A390" width="800"/></a> <p class="a-image-text">Opdateret 18. august kl. 14:00. Kilde: Statens Serum Institut</p>
# </div>
# <div class="o-content-block__content--push-bottom">
# <hr/>
# <h3>5.2 Dødsfald: dødsdato</h3>
# <p>Dødsfald med COVID-19-infektion, fordelt på dødsdato</p>
# </div>
# <div class="o-content-block__content o-content-block__content--push-bottom">
# <a><img alt="Søjlediagram, der viser antal dødsfald med påvist COVID-19-infektion fordelt på dødsdato. X-aksen viser dato, og Y-aksen viser antal personer." height="480" src="/-/media/Udgivelser/2020/Corona/Overvågningsdata/Data-1808/fig_3_1.ashx?h=480&amp;la=da&amp;w=800&amp;hash=53F077E66510950C71E75BD50E9242A1BF073B9E" width="800"/></a> <p class="a-image-text">Opdateret 18. august kl. 14:00. Kilde: Statens Serum Institut</p>
# </div>
# <div class="o-content-block__content--push-bottom">
# <hr/>
# <h3>5.3 Dødsfald: køn og alder - akkumuleret</h3>
# <p>Køns- og aldersfordeling for døde personer med COVID-19 infektion - akkumuleret</p>
# <table>
# <tbody>
# <tr>
# <td>Aldersgruppe </td>
# <td>Bekræftede COVID-19 tilfælde i at </td>
# <td>Dødsfald i alt</td>
# <td>Andel af døde i forhold til bekræftede</td>
# <td style="text-align: left;">Døde med underliggende sygdom<sup>1</sup></td>
# <td style="text-align: left;">Andel af døde med underliggende sygdom<sup>1</sup></td>
# <td>Dødsfald kvinder </td>
# <td>Dødsfald mænd</td>
# </tr>
# <tr>
# <td>0-59<sup>2</sup></td>
# <td>11.880</td>
# <td>17</td>
# <td>1 %</td>
# <td>12</td>
# <td>75 %</td>
# <td>5</td>
# <td>12</td>
# </tr>
# <tr>
# <td>60-69</td>
# <td>1.647</td>
# <td>59</td>
# <td>4 %</td>
# <td>45</td>
# <td>
#             76 %
#             </td>
# <td>22</td>
# <td>37</td>
# </tr>
# <tr>
# <td>70-79</td>
# <td>1.189</td>
# <td>180</td>
# <td>15 %</td>
# <td>149</td>
# <td>83 %</td>
# <td>53</td>
# <td>127</td>
# </tr>
# <tr>
# <td>80-89</td>
# <td>865</td>
# <td>236</td>
# <td>27 %</td>
# <td>198</td>
# <td>84 %</td>
# <td>103</td>
# <td>133</td>
# </tr>
# <tr>
# <td>
#             90+
#             </td>
# <td>274</td>
# <td>129</td>
# <td>47 %</td>
# <td>109</td>
# <td>84 %</td>
# <td>88</td>
# <td>41</td>
# </tr>
# <tr>
# <td><strong>I alt</strong></td>
# <td><strong>15.855</strong></td>
# <td><strong>621</strong></td>
# <td><strong>4 %</strong></td>
# <td><strong>513</strong></td>
# <td><strong>83 %</strong></td>
# <td><strong>271</strong></td>
# <td><strong>350</strong></td>
# </tr>
# </tbody>
# </table>
# <p>
# <span class="a-italicgrey-text">Opdateret <strong>18. august kl. 14.00</strong></span></p>
# <span class="a-italicgrey-text"><span class="a-italicgrey-text"></span>Kilde: Statens Serum Institut, COVID-19 overvågningsrapport. <br/>
# 1) Underliggende sygdom er defineret som indlæggelse indenfor de sidste 5 år med bl.a. følgende diagnoser diabetes, cancer, kronisk lungesygdom, hjerte-kar sygdomme og hæmatologiske sygdomme.<br/>
# 2) Flere aldersgrupper er slået sammen til aldersgruppen 0-59 år. Dette er af diskretionshensyn i forhold til patienterne.</span>
# </div>
# <div class="m-factbox">
# <!-- Styled as h6 -->
# <h3 class="m-factbox__head">Det europæiske agentur for smitsomme sygdomme</h3>
# <div class="m-factbox__content">
# <p>European Centre for Disease Prevention and Control (ECDC) følger løbende spredningen af coronavirus/COVID-19 med data, som indberettes dagligt af de nationale myndigheder.</p>
# <p> </p>
# <p><a href="https://www.ecdc.europa.eu/en/novel-coronavirus-china" rel="noopener noreferrer" target="_blank">Find de seneste oplysninger her</a></p>
# <h3>WHO</h3>
# <p>Verdenssundhedsorganisationen WHO under FN følger spredningen med coronavirus/COVID-19 i mere end 100 lande verden over på baggrund af data, som dagligt indberettes af nationale myndigheder. </p>
# <p> </p>
# <p><a href="https://www.who.int/emergencies/diseases/novel-coronavirus-2019/situation-reports/" rel="noopener noreferrer" target="_blank">Find seneste tal i WHO's Situation Reports</a>
# </p>
# <h3>Johns Hopkins University
# </h3>
# <p>Johns Hopkins University følger løbende spredningen af COVID-19/coronavirus på verdensplan i antallet af smittede, døde og raskmeldte. Oplysningerne er tilgængelige på et interaktivt verdenskort. Vær opmærksom på, at denne data ikke opdateres samtidig med data på Sundhedsstyrelsens hjemmeside.</p>
# <p> </p>
# <p><a href="https://www.arcgis.com/apps/opsdashboard/index.html#/bda7594740fd40299423467b48e9ecf6" rel="noopener noreferrer" target="_blank">Følg smittespredningen på Johns Hopkins interaktive kort</a></p>
# </div>
# <!-- CTA -->
# </div>
# </div>
# <!-- infoboxes -->
# </div>
# <div class="m-page-date m-page-date--bottom">
#             Opdateret  20 AUG 2020
#         </div>
# </article>
# </main> <div class="o-simple-spot o-module--bright-blue">
# <div class="u-site-container o-simple-spot__container">
# <div class="o-simple-spot__text-content">
# <div class="o-simple-spot__header">
# <h4 class="o-simple-spot__title">Tilmeld dig og få nyheder om COVID-19 i din indbakke</h4>
# </div>
# <p class="o-simple-spot__manchet"></p>
# </div>
# <div class="o-simple-spot__button-container">
# <a class="m-link-icon m-link-icon--button m-link-icon--button-02 o-simple-spot__button o-simple-spot__button--expand-width" href="/da/Nyheder/Nyhedsmail"> <span class="a-icon m-link-icon__icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_right_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span class="m-link-icon--button-label">Tilmeld</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <footer class="o-footer">
# <div class="o-footer__inner u-grid u-grid--wrap u-site-container">
# <div class="o-footer__column u-grid__cell u-grid__cell--width-50@md u-grid__cell--width-100">
# <div class="u-grid u-grid--wrap u-grid--no-gutter">
# <div class="u-grid__cell u-grid__cell--width-50@md u-grid__cell--width-100">
# <h3 class="o-footer__header">Kontakt os</h3>
# <svg class="a-health-icons o-footer__health-icons o-footer__health-icons--desktop" viewbox="0 0 246.67 61.34" xmlns="http://www.w3.org/2000/svg"><defs></defs><title>Sundhed for alle</title><path class="a" d="M246.67,30.67A30.67,30.67,0,1,1,216,0,30.67,30.67,0,0,1,246.67,30.67ZM137.09,1H121.25V22.75H99.52V38.6h21.73V60.32h15.84V38.6h21.73V22.75H137.09ZM54.28,0C41.81,0,37,11.26,37,11.26S32.22,0,19.75,0C5.7,0,0,12.23,0,19.4,0,33.94,17.09,52,37,61.34,56.94,52,74,33.94,74,19.4,74,12.23,68.33,0,54.28,0Z"></path></svg>
# </div>
# <div class="u-grid__cell u-grid__cell--width-50@md u-grid__cell--width-100">
# <h4 class="o-footer__sub-header">Adresse</h4>
# <address class="o-footer__address">
#                         Sundhedsstyrelsen<br/>Islands Brygge 67<br/>2300 København S<br/><br/>
# <p><a class="o-footer__content-link" href="/da/Om-os/Kontakt-og-besoeg/Fakturering_-EAN-og-CVR">CVR: 12070918<br/>
# VAT: DK33 47 35 32<br/>
# EAN: 5798000363007</a></p>
# </address>
# <h4 class="o-footer__sub-header o-footer__sub-header--space-top">Mail</h4>
# <a class="o-footer__content-link o-footer__underlined" href="mailto: sst@sst.dk" title="e-mail adresse">sst@sst.dk</a>
# <h4 class="o-footer__sub-header o-footer__sub-header--space-top">Telefon</h4>
# <a class="o-footer__content-link" href="tel:72 22 74 00" title="telefon">Tlf. 72 22 74 00</a>
# <h4 class="o-footer__sub-header o-footer__sub-header--space-top">Følg os</h4>
# <div class="o-footer__content-link-wrapper">
# <p><a class="o-footer__content-link" href="https://twitter.com/SSTSundhed" rel="noopener noreferrer" target="_blank" title="twitter">Twitter</a><a class="o-footer__content-link" href="https://www.google.dk/url?sa=t&amp;rct=j&amp;q=&amp;esrc=s&amp;source=web&amp;cd=1&amp;cad=rja&amp;uact=8&amp;ved=2ahUKEwj5rL6is-_nAhUR-qQKHQN2CzYQFjAAegQIARAB&amp;url=https%3A%2F%2Fdk.linkedin.com%2Fcompany%2Fsundhedsstyrelsen&amp;usg=AOvVaw320KzXqPmumM4EJfodi_3q" rel="noopener noreferrer" target="_blank" title="facebook">LinkedIn</a><a href="https://www.facebook.com/sundhedsstyrelsenDK/" rel="noopener noreferrer" target="_blank">Facebook</a></p>
# </div>
# </div>
# </div>
# </div>
# <div class="o-footer__column u-grid__cell u-grid__cell--width-50@md u-grid__cell--width-100">
# <div class="u-grid u-grid--no-gutter">
# <div class="u-grid__cell">
# <div class="o-subscribe">
# <h4 class="o-subscribe__header o-footer__sub-header">Nyhedsabonnement </h4>
# <p class="o-subscribe__text"> Tilmeld dig til vores nyhedsabonnement og få vores nyheder direkte i din indbakke</p>
# <a class="m-link-icon m-link-icon--button m-link-icon--button-02 o-subscribe__link" href="/da/Nyheder/Nyhedsmail"> <span class="a-icon m-link-icon__icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_right_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span class="m-link-icon--button-label">Tilmeld nyhedsabonnement</span>
# </a> </div>
# </div>
# </div>
# <div class="o-footer__shortcuts o-footer__sub-item--dark-bg" data-behavior="shortcuts-footer">
# <label class="o-shortcuts__label" for="footer-shortcut">
# <input class="o-shortcuts__checkbox" id="footer-shortcut" type="checkbox"/>
# <div class="m-link-icon o-shortcuts__link m-link-icon--reverted" title="Genveje">
# <span class="a-icon m-link-icon__icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Icon_Function_ChevronDown" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span class="m-link-icon__label">Genveje</span>
# </div>
# <nav class="o-shortcuts__nav o-footer__shortcuts-nav" role="navigation">
# <h4 class="o-footer__sub-header o-footer__sub-header--space-top">Genveje</h4>
# <div class="u-grid u-grid--no-gutter u-grid--wrap">
# <div class="u-grid__cell u-grid__cell--width-50">
# <div data-ref="footer-shortcuts-first">
# <a class="m-link-icon m-link-icon--circle o-footer__shortcut" href="/da/Om-os/Databeskyttelsespolitik/Cookies" title="">
# <span class="a-icon m-link-icon__icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_right_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span class="m-link-icon__label">Cookies</span>
# </a>
# <a class="m-link-icon m-link-icon--circle o-footer__shortcut" href="/da/Nyheder" title="">
# <span class="a-icon m-link-icon__icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_right_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span class="m-link-icon__label">Nyheder</span>
# </a>
# <a class="m-link-icon m-link-icon--circle o-footer__shortcut" href="/da/Om-os/Presse-og-nyt/Pressekontakt" title="">
# <span class="a-icon m-link-icon__icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_right_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span class="m-link-icon__label">Presse</span>
# </a>
# <a class="m-link-icon m-link-icon--circle o-footer__shortcut" href="/da/Udgivelser" title="">
# <span class="a-icon m-link-icon__icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_right_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span class="m-link-icon__label">Udgivelser</span>
# </a>
# <a class="m-link-icon m-link-icon--circle o-footer__shortcut" href="/da/corona" title="">
# <span class="a-icon m-link-icon__icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_right_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span class="m-link-icon__label">Coronavirus</span>
# </a>
# </div>
# </div>
# <div class="u-grid__cell u-grid__cell--width-50">
# <div data-ref="footer-shortcuts-second">
# <a class="m-link-icon m-link-icon--circle o-footer__shortcut" href="/da/Puljer" title="">
# <span class="a-icon m-link-icon__icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_right_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span class="m-link-icon__label">Puljer</span>
# </a>
# <a class="m-link-icon m-link-icon--circle o-footer__shortcut" href="/da/Opgaver/Patientforloeb-og-kvalitet/Nationale-kliniske-retningslinjer-NKR" title="">
# <span class="a-icon m-link-icon__icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_right_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span class="m-link-icon__label">NKR</span>
# </a>
# <a class="m-link-icon m-link-icon--circle o-footer__shortcut" href="/da/Om-os/Strategi-og-grundlag/Habilitet" title="">
# <span class="a-icon m-link-icon__icon">
# <svg class="a-icon__asset">
# <use xlink:href="#Arrow_right_icon" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span class="m-link-icon__label">Habilitet</span>
# </a>
# </div>
# </div>
# </div>
# </nav>
# </label>
# <svg class="a-health-icons o-footer__health-icons o-footer__health-icons--mobile" viewbox="0 0 246.67 61.34" xmlns="http://www.w3.org/2000/svg"><defs></defs><title>Sundhed for alle</title><path class="a" d="M246.67,30.67A30.67,30.67,0,1,1,216,0,30.67,30.67,0,0,1,246.67,30.67ZM137.09,1H121.25V22.75H99.52V38.6h21.73V60.32h15.84V38.6h21.73V22.75H137.09ZM54.28,0C41.81,0,37,11.26,37,11.26S32.22,0,19.75,0C5.7,0,0,12.23,0,19.4,0,33.94,17.09,52,37,61.34,56.94,52,74,33.94,74,19.4,74,12.23,68.33,0,54.28,0Z"></path></svg>
# </div>
# </div>
# </div>
# </footer>
# <script src="/dist/js/behaviors-ff451966.pkg.js" sri="sha256-AF7NxESPf+eTrurLcXXLTOFJX84CYLBK8MLfby/QirU= sha384-gnnCORrgJdm8kyKJZWVTBTVu+aDbwtDUXE9FlyTN7pCqQd2ovSEkA5p8GyCA09NX sha512-S1wqLADSFkUDQSUGygB9oSR8KEyAlT7id7/s9zmAmUiQpxUJW8uYVEF2eqWfZGkwjSL7M2wNajQotLqS7oFzcA=="></script>
# <!-- www.Cludo.com search start JS -->
# <!--[if lte IE 9]>
#     <script src="https://api.cludo.com/scripts/xdomain.js" slave="https://api.cludo.com/proxy.html"></script>
# <![endif]-->
# <!-- www.Cludo.com search end JS -->
# <!-- www.Cludo.com Search body init script start -->
# <script src="//ajax.googleapis.com/ajax/libs/jquery/3.3.1/jquery.min.js"></script>
# <script src="//customer.cludo.com/scripts/bundles/search-script.min.js" type="text/javascript"></script>
# <script src="//customer.cludo.com/assets/197/10832/cludo-search.min.js" type="text/javascript"></script>
# <script>
#     var CludoSearch;
#     (function () {
#         var cludoSettings = {
#             customerId: 197,
#             engineId: 10832,
#             searchUrl: "/Soegeresultater",
#             searchInputs: ["cludo-nav-search","cludo-search-bar"],
#             facets: ["Category", "Subject"],
#             loading: "<img src='//customer.cludo.com/img/loading.gif' alt='Loading' class='loading' role='progressbar' /><div class='loading-more-text'>Henter resultater. Vent venligst...</div>",
#             customCallbackAfterSearch: function () {
#                 AppCludo.init();
#             }
#         };
#         CludoSearch= new Cludo(cludoSettings);
#         CludoSearch.translateProvider.translations["da"]["your_search_on"] = "Din søgning ";
#         CludoSearch.translateProvider.translations["da"]["in_category"] = " i kategori <b>{{value}}</b> ";
#         CludoSearch.translateProvider.translations["da"]["and"] = " og ";
#         CludoSearch.init();
#     })();
# </script>
# <!-- www.Cludo.com Search body init script start -->
# <script type="text/javascript">
#             /*<![CDATA[*/
#             (function () {
#                 var sz = document.createElement('script');
#                 sz.type = 'text/javascript';
#                 sz.async = true;
#                 sz.src = '//siteimproveanalytics.com/js/siteanalyze_26972.js';
#                 var s = document.getElementsByTagName('script')[0];
#                 s.parentNode.insertBefore(sz, s);
#             })();
#                 /*]]>*/
#         </script>
# </body>
# </html>

# %%
#John
url = f'https://coronavirus.jhu.edu/map.html'
response = connector.get(url,'review_getter')
html = response[0].text
soup = BeautifulSoup(html,'html.parser')
score_text_elem = soup.find_all(class_ ='widget-body flex-fluid full-width flex-vertical overflow-y-auto overflow-x-hidden')
#score = re.search("\d+\.\d+",score_text_elem.text).group()
score_text_elem
#html
# Out:
# []

# %%
#mere john
url = f'https://coronavirus.jhu.edu/testing/tracker/overview'
response = connector.get(url,'review_getter')
html = response[0].text
soup = BeautifulSoup(html,'html.parser')
score_text_elem = soup.find_all(class_ ='number number--teal')
#score = re.search("\d+\.\d+",score_text_elem.text).group()
score_text_elem
#html
# Out:
# []

# %%
#WIKI
wiki='https://en.wikipedia.org/wiki/Template:COVID-19_pandemic_data'
