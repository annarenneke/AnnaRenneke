# %%
#Importing packages
import requests
import pandas as pd

# %%
#DMI requires a key to access their API
api_key = '12a4bffe-21d5-4154-96e5-12bf959cc1dd'

# %%
#Request API - observation
url = 'https://dmigw.govcloud.dk/metObs/v1/observation'
r = requests.get(url ,params={'api-key': api_key})
print(r, r.url)
# Out:
# <Response [200]> https://dmigw.govcloud.dk/metObs/v1/observation?api-key=12a4bffe-21d5-4154-96e5-12bf959cc1dd

# %%
#Extract JSON data
json = r.json()
json
# Out:
# [{'_id': '39ca9624-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '04320',
#   'timeCreated': 1598132484265334.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.4},
#  {'_id': '39ca9336-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '04320',
#   'timeCreated': 1598132484265260.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1.1},
#  {'_id': '39ca8ff8-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '04320',
#   'timeCreated': 1598132484265180.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 162.0},
#  {'_id': '39ca8cc4-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '04320',
#   'timeCreated': 1598132484265095.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 6.3},
#  {'_id': '39ca8918-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '04320',
#   'timeCreated': 1598132484265012.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 2.5},
#  {'_id': '39ca8120-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'radia_glob',
#   'stationId': '04320',
#   'timeCreated': 1598132484264835.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 12.0},
#  {'_id': '39c9ce56-e4c0-11ea-9628-b6de4a65a09e',
#   'parameterId': 'visib_mean_last10min',
#   'stationId': '04320',
#   'timeCreated': 1598132484260259.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 50000.0},
#  {'_id': '39c9c186-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'visibility',
#   'stationId': '04320',
#   'timeCreated': 1598132484259888.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 50000.0},
#  {'_id': '39c9be84-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'cloud_height',
#   'stationId': '04320',
#   'timeCreated': 1598132484259824.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1250.0},
#  {'_id': '39c9b7c2-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'cloud_cover',
#   'stationId': '04320',
#   'timeCreated': 1598132484259673.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 90.0},
#  {'_id': '39c972a8-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '04320',
#   'timeCreated': 1598132484257867.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1008.5},
#  {'_id': '39c97096-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '04320',
#   'timeCreated': 1598132484257819.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1007.1},
#  {'_id': '39c96ac4-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '04320',
#   'timeCreated': 1598132484257698.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 76.0},
#  {'_id': '2e2a5e44-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '04272',
#   'timeCreated': 1598132464760391.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1005.3},
#  {'_id': '2e2a58fe-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'precip_past10min',
#   'stationId': '04272',
#   'timeCreated': 1598132464760281.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '2e2a55ca-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'visibility',
#   'stationId': '04272',
#   'timeCreated': 1598132464760210.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 50000.0},
#  {'_id': '2e2a31bc-e4c0-11ea-9628-b6de4a65a09e',
#   'parameterId': 'visib_mean_last10min',
#   'stationId': '04272',
#   'timeCreated': 1598132464759285.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 50000.0},
#  {'_id': '216366a6-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06197',
#   'timeCreated': 1598132443323773.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 3.2},
#  {'_id': '21636520-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06197',
#   'timeCreated': 1598132443323734.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 4.6},
#  {'_id': '2163637c-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06197',
#   'timeCreated': 1598132443323692.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 231.0},
#  {'_id': '216361c4-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_grass',
#   'stationId': '06197',
#   'timeCreated': 1598132443323649.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 18.3},
#  {'_id': '21636034-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06197',
#   'timeCreated': 1598132443323609.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 18.9},
#  {'_id': '21635e86-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06197',
#   'timeCreated': 1598132443323567.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 17.5},
#  {'_id': '21635ca6-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'sun_last10min_glob',
#   'stationId': '06197',
#   'timeCreated': 1598132443323520.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '21635918-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'radia_glob',
#   'stationId': '06197',
#   'timeCreated': 1598132443323442.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '21630012-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '06197',
#   'timeCreated': 1598132443321149.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1011.4},
#  {'_id': '2162fe28-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '06197',
#   'timeCreated': 1598132443321101.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1008.4},
#  {'_id': '2162fbe4-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'precip_past10min',
#   'stationId': '06197',
#   'timeCreated': 1598132443321044.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '2162f806-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06197',
#   'timeCreated': 1598132443320957.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 91.0},
#  {'_id': '215a4aee-e4c0-11ea-b42a-e22e6bb15505',
#   'parameterId': 'temp_soil',
#   'stationId': '06197',
#   'timeCreated': 1598132443264109.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 20.2},
#  {'_id': '2159cb82-e4c0-11ea-8135-46818c941500',
#   'parameterId': 'leav_hum_dur_past10min',
#   'stationId': '06197',
#   'timeCreated': 1598132443260848.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '2159b53e-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'weather',
#   'stationId': '06123',
#   'timeCreated': 1598132443260260.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 181.0},
#  {'_id': '2159af58-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'visibility',
#   'stationId': '06123',
#   'timeCreated': 1598132443260128.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 19000.0},
#  {'_id': '21598c3a-e4c0-11ea-9628-b6de4a65a09e',
#   'parameterId': 'visib_mean_last10min',
#   'stationId': '06123',
#   'timeCreated': 1598132443259235.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 19500.0},
#  {'_id': '21596624-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06123',
#   'timeCreated': 1598132443258225.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 7.9},
#  {'_id': '21596494-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06123',
#   'timeCreated': 1598132443258185.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 9.9},
#  {'_id': '2159628c-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06123',
#   'timeCreated': 1598132443258137.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 246.0},
#  {'_id': '21595fee-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06123',
#   'timeCreated': 1598132443258070.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 18.7},
#  {'_id': '21595f44-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '06123',
#   'timeCreated': 1598132443258054.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1009.8},
#  {'_id': '21595d6e-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06123',
#   'timeCreated': 1598132443258007.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 15.6},
#  {'_id': '21595c24-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '06123',
#   'timeCreated': 1598132443257980.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1009.4},
#  {'_id': '21595a9e-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'sun_last10min_glob',
#   'stationId': '06123',
#   'timeCreated': 1598132443257938.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '215955bc-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06123',
#   'timeCreated': 1598132443257839.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 82.0},
#  {'_id': '21595526-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'radia_glob',
#   'stationId': '06123',
#   'timeCreated': 1598132443257821.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '20dc763c-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '04250',
#   'timeCreated': 1598132442439437.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 2.5},
#  {'_id': '20dc74ca-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '04250',
#   'timeCreated': 1598132442439399.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 3.5},
#  {'_id': '20dc7330-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '04250',
#   'timeCreated': 1598132442439359.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 274.0},
#  {'_id': '20dc7178-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '04250',
#   'timeCreated': 1598132442439314.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 4.9},
#  {'_id': '20dc6fa2-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '04250',
#   'timeCreated': 1598132442439271.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 4.7},
#  {'_id': '20dc6bf6-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'radia_glob',
#   'stationId': '04250',
#   'timeCreated': 1598132442439187.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 24.0},
#  {'_id': '20d855a2-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06119',
#   'timeCreated': 1598132442412388.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 8.4},
#  {'_id': '20d853ea-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06119',
#   'timeCreated': 1598132442412345.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 9.4},
#  {'_id': '20d85214-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06119',
#   'timeCreated': 1598132442412298.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 209.0},
#  {'_id': '20d84fee-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06119',
#   'timeCreated': 1598132442412245.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 17.7},
#  {'_id': '20d84cd8-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06119',
#   'timeCreated': 1598132442412173.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 16.3},
#  {'_id': '20d80e62-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '04250',
#   'timeCreated': 1598132442410564.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1012.7},
#  {'_id': '20d80cbe-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '04250',
#   'timeCreated': 1598132442410522.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1002.3},
#  {'_id': '20d80ad4-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'precip_past10min',
#   'stationId': '04250',
#   'timeCreated': 1598132442410475.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '20d807f0-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '04250',
#   'timeCreated': 1598132442410408.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 99.0},
#  {'_id': '20d5a2b2-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '06169',
#   'timeCreated': 1598132442394700.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1008.7},
#  {'_id': '20d5a10e-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '06169',
#   'timeCreated': 1598132442394658.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1006.8},
#  {'_id': '20d59f2e-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'precip_past10min',
#   'stationId': '06169',
#   'timeCreated': 1598132442394612.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '20d59c4a-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06169',
#   'timeCreated': 1598132442394545.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 78.0},
#  {'_id': '20d58002-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06072',
#   'timeCreated': 1598132442393812.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 3.7},
#  {'_id': '20d57e4a-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06072',
#   'timeCreated': 1598132442393768.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 5.6},
#  {'_id': '20d57c4c-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06072',
#   'timeCreated': 1598132442393717.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 197.0},
#  {'_id': '20d57a6c-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_grass',
#   'stationId': '06072',
#   'timeCreated': 1598132442393670.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 14.1},
#  {'_id': '20d578b4-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06072',
#   'timeCreated': 1598132442393626.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 15.0},
#  {'_id': '20d576de-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06072',
#   'timeCreated': 1598132442393579.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 12.8},
#  {'_id': '20d574cc-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'sun_last10min_glob',
#   'stationId': '06072',
#   'timeCreated': 1598132442393528.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '20d571d4-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'radia_glob',
#   'stationId': '06072',
#   'timeCreated': 1598132442393457.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '20d307fa-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '06119',
#   'timeCreated': 1598132442377632.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1010.2},
#  {'_id': '20d30656-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '06119',
#   'timeCreated': 1598132442377591.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1008.0},
#  {'_id': '20d30476-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'precip_past10min',
#   'stationId': '06119',
#   'timeCreated': 1598132442377544.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '20d301a6-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06119',
#   'timeCreated': 1598132442377478.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 92.0},
#  {'_id': '20d2f22e-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06169',
#   'timeCreated': 1598132442377078.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 11.2},
#  {'_id': '20d2efcc-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06169',
#   'timeCreated': 1598132442377016.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 13.1},
#  {'_id': '20d2ed1a-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06169',
#   'timeCreated': 1598132442376949.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 248.0},
#  {'_id': '20d2ea04-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06169',
#   'timeCreated': 1598132442376873.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 18.7},
#  {'_id': '20d2e5e0-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06169',
#   'timeCreated': 1598132442376774.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 14.7},
#  {'_id': '20ceb8e4-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '06072',
#   'timeCreated': 1598132442349393.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1008.0},
#  {'_id': '20ceb740-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '06072',
#   'timeCreated': 1598132442349352.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1000.6},
#  {'_id': '20ceb560-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'precip_past10min',
#   'stationId': '06072',
#   'timeCreated': 1598132442349305.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '20ceb27c-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06072',
#   'timeCreated': 1598132442349238.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 87.0},
#  {'_id': '20ce86d0-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06081',
#   'timeCreated': 1598132442348111.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 11.8},
#  {'_id': '20ce8504-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06081',
#   'timeCreated': 1598132442348066.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 15.4},
#  {'_id': '20ce831a-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06081',
#   'timeCreated': 1598132442348017.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 238.0},
#  {'_id': '20ce80e0-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06081',
#   'timeCreated': 1598132442347962.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 18.6},
#  {'_id': '20ce7d98-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06081',
#   'timeCreated': 1598132442347886.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 15.1},
#  {'_id': '20cdb89a-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'visibility',
#   'stationId': '06169',
#   'timeCreated': 1598132442342842.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 21000.0},
#  {'_id': '20ccdeb6-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '06081',
#   'timeCreated': 1598132442337255.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1007.7},
#  {'_id': '20ccdcd6-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '06081',
#   'timeCreated': 1598132442337209.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1005.6},
#  {'_id': '20ccd952-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06081',
#   'timeCreated': 1598132442337130.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 80.0},
#  {'_id': '20cc4604-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06151',
#   'timeCreated': 1598132442333345.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 8.9},
#  {'_id': '20cc444c-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06151',
#   'timeCreated': 1598132442333301.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 10.5},
#  {'_id': '20cc4262-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06151',
#   'timeCreated': 1598132442333253.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 230.0},
#  {'_id': '20cc401e-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06151',
#   'timeCreated': 1598132442333198.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 18.9},
#  {'_id': '20cc3c72-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06151',
#   'timeCreated': 1598132442333114.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 16.3},
#  {'_id': '20cb8250-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'visibility',
#   'stationId': '06119',
#   'timeCreated': 1598132442328338.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 21000.0},
#  {'_id': '20cb7ec2-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'cloud_cover',
#   'stationId': '06119',
#   'timeCreated': 1598132442328258.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '20c7d74a-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '06049',
#   'timeCreated': 1598132442304298.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1007.4},
#  {'_id': '20c7d51a-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '06049',
#   'timeCreated': 1598132442304243.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 996.9},
#  {'_id': '20c7d13c-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06049',
#   'timeCreated': 1598132442304156.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 94.0},
#  {'_id': '20c7c9b2-e4c0-11ea-9628-b6de4a65a09e',
#   'parameterId': 'visib_mean_last10min',
#   'stationId': '06119',
#   'timeCreated': 1598132442303964.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 21200.0},
#  {'_id': '20c66ec8-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06049',
#   'timeCreated': 1598132442295066.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 4.6},
#  {'_id': '20c66d42-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06049',
#   'timeCreated': 1598132442295028.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 6.3},
#  {'_id': '20c66b8a-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06049',
#   'timeCreated': 1598132442294985.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 209.0},
#  {'_id': '20c66982-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06049',
#   'timeCreated': 1598132442294934.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 14.5},
#  {'_id': '20c665f4-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06049',
#   'timeCreated': 1598132442294856.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 13.5},
#  {'_id': '20c61860-e4c0-11ea-9628-b6de4a65a09e',
#   'parameterId': 'visib_mean_last10min',
#   'stationId': '06169',
#   'timeCreated': 1598132442292868.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 21500.0},
#  {'_id': '20c5d936-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'weather',
#   'stationId': '04250',
#   'timeCreated': 1598132442291239.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 110.0},
#  {'_id': '20c5d706-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'visibility',
#   'stationId': '04250',
#   'timeCreated': 1598132442291189.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 3400.0},
#  {'_id': '20c5d29c-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'cloud_cover',
#   'stationId': '04250',
#   'timeCreated': 1598132442291085.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 112.0},
#  {'_id': '20c5ca5e-e4c0-11ea-8135-46818c941500',
#   'parameterId': 'leav_hum_dur_past10min',
#   'stationId': '06072',
#   'timeCreated': 1598132442290875.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 4.0},
#  {'_id': '20c3e32e-e4c0-11ea-9628-b6de4a65a09e',
#   'parameterId': 'visib_mean_last10min',
#   'stationId': '04250',
#   'timeCreated': 1598132442278403.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 3400.0},
#  {'_id': '20c388d4-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '06151',
#   'timeCreated': 1598132442276078.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1010.2},
#  {'_id': '20c38640-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '06151',
#   'timeCreated': 1598132442276011.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1009.9},
#  {'_id': '20c381e0-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06151',
#   'timeCreated': 1598132442275916.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 85.0},
#  {'_id': '20c368c2-e4c0-11ea-b42a-e22e6bb15505',
#   'parameterId': 'temp_soil',
#   'stationId': '06072',
#   'timeCreated': 1598132442275281.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 17.2},
#  {'_id': '20c310fc-e4c0-11ea-8135-46818c941500',
#   'parameterId': 'precip_dur_past10min',
#   'stationId': '06169',
#   'timeCreated': 1598132442273033.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '20c17954-e4c0-11ea-9628-b6de4a65a09e',
#   'parameterId': 'visib_mean_last10min',
#   'stationId': '06049',
#   'timeCreated': 1598132442262590.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 20000.0},
#  {'_id': '20c177ba-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'visibility',
#   'stationId': '06049',
#   'timeCreated': 1598132442262529.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 20000.0},
#  {'_id': '20c17530-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'cloud_height',
#   'stationId': '06049',
#   'timeCreated': 1598132442262469.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 800.0},
#  {'_id': '20c17012-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'cloud_cover',
#   'stationId': '06049',
#   'timeCreated': 1598132442262358.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 40.0},
#  {'_id': '20c0e3cc-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '04271',
#   'timeCreated': 1598132442258746.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 2.2},
#  {'_id': '20c0e0b6-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '04271',
#   'timeCreated': 1598132442258674.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 2.5},
#  {'_id': '20c0dc60-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '04271',
#   'timeCreated': 1598132442258554.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 199.0},
#  {'_id': '20c0da08-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '04271',
#   'timeCreated': 1598132442258494.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 11.2},
#  {'_id': '20c0d7b0-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '04271',
#   'timeCreated': 1598132442258435.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 7.9},
#  {'_id': '20c0d21a-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'radia_glob',
#   'stationId': '04271',
#   'timeCreated': 1598132442258311.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 89.0},
#  {'_id': '20c0ce14-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '04271',
#   'timeCreated': 1598132442258191.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1011.8},
#  {'_id': '20c0cac2-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '04271',
#   'timeCreated': 1598132442258113.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1011.2},
#  {'_id': '20c0c3a6-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '04271',
#   'timeCreated': 1598132442257958.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 80.0},
#  {'_id': '1e171d4e-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '06073',
#   'timeCreated': 1598132437790659.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1008.5},
#  {'_id': '1e171b78-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '06073',
#   'timeCreated': 1598132437790613.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1007.8},
#  {'_id': '1e1717ae-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06073',
#   'timeCreated': 1598132437790529.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 83.0},
#  {'_id': '1e16bb06-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06073',
#   'timeCreated': 1598132437788141.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 7.7},
#  {'_id': '1e16b958-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06073',
#   'timeCreated': 1598132437788098.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 10.1},
#  {'_id': '1e16b7a0-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06073',
#   'timeCreated': 1598132437788056.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 235.0},
#  {'_id': '1e16b584-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06073',
#   'timeCreated': 1598132437788004.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 18.0},
#  {'_id': '1e16b1ba-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06073',
#   'timeCreated': 1598132437787921.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 15.0},
#  {'_id': '1e12e26a-e4c0-11ea-8135-46818c941500',
#   'parameterId': 'precip_dur_past10min',
#   'stationId': '06154',
#   'timeCreated': 1598132437762960.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '1e12c8ac-e4c0-11ea-9628-b6de4a65a09e',
#   'parameterId': 'visib_mean_last10min',
#   'stationId': '06154',
#   'timeCreated': 1598132437762303.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 25900.0},
#  {'_id': '1e12c2da-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'visibility',
#   'stationId': '06154',
#   'timeCreated': 1598132437762179.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 25000.0},
#  {'_id': '1e12403a-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '06154',
#   'timeCreated': 1598132437758784.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1010.5},
#  {'_id': '1e123e96-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '06154',
#   'timeCreated': 1598132437758742.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1005.0},
#  {'_id': '1e123c84-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'precip_past10min',
#   'stationId': '06154',
#   'timeCreated': 1598132437758693.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '1e1238f6-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06154',
#   'timeCreated': 1598132437758597.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 5.6},
#  {'_id': '1e1237ac-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06154',
#   'timeCreated': 1598132437758594.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 79.0},
#  {'_id': '1e12375c-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06154',
#   'timeCreated': 1598132437758558.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 8.5},
#  {'_id': '1e123540-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06154',
#   'timeCreated': 1598132437758509.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 239.0},
#  {'_id': '1e1231ee-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06154',
#   'timeCreated': 1598132437758427.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 18.4},
#  {'_id': '1e122c62-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06154',
#   'timeCreated': 1598132437758308.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 14.7},
#  {'_id': '1d7cdfc2-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '06149',
#   'timeCreated': 1598132436779828.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1011.4},
#  {'_id': '1d7cde00-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '06149',
#   'timeCreated': 1598132436779784.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1010.8},
#  {'_id': '1d7cdbda-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'precip_past10min',
#   'stationId': '06149',
#   'timeCreated': 1598132436779734.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '1d7cd6a8-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06149',
#   'timeCreated': 1598132436779623.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 83.0},
#  {'_id': '1d7c6c04-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06149',
#   'timeCreated': 1598132436776864.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 10.0},
#  {'_id': '1d7c6a7e-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06149',
#   'timeCreated': 1598132436776826.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 12.0},
#  {'_id': '1d7c68da-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06149',
#   'timeCreated': 1598132436776784.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 238.0},
#  {'_id': '1d7c66fa-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06149',
#   'timeCreated': 1598132436776737.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 19.3},
#  {'_id': '1d7c63da-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06149',
#   'timeCreated': 1598132436776688.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 16.4},
#  {'_id': '1d7c61f0-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'sun_last10min_glob',
#   'stationId': '06149',
#   'timeCreated': 1598132436776609.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '1d7c5d40-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'radia_glob',
#   'stationId': '06149',
#   'timeCreated': 1598132436776511.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1.0},
#  {'_id': '1d7a4d84-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06093',
#   'timeCreated': 1598132436762977.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 10.3},
#  {'_id': '1d7a4ba4-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06093',
#   'timeCreated': 1598132436762930.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 12.7},
#  {'_id': '1d7a4974-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06093',
#   'timeCreated': 1598132436762876.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 231.0},
#  {'_id': '1d7a4668-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06093',
#   'timeCreated': 1598132436762804.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 19.3},
#  {'_id': '1d7a3f9c-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06093',
#   'timeCreated': 1598132436762669.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 15.4},
#  {'_id': '1d7a207a-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '06093',
#   'timeCreated': 1598132436761825.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1008.6},
#  {'_id': '1d7a1e7c-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '06093',
#   'timeCreated': 1598132436761776.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1008.2},
#  {'_id': '1d7a1986-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06093',
#   'timeCreated': 1598132436761679.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 78.0},
#  {'_id': '1b17d5e8-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06124',
#   'timeCreated': 1598132432762220.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 3.7},
#  {'_id': '1b17d3fe-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06124',
#   'timeCreated': 1598132432762173.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 6.4},
#  {'_id': '1b17d124-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06124',
#   'timeCreated': 1598132432762105.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 220.0},
#  {'_id': '1b17cd50-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06124',
#   'timeCreated': 1598132432762013.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 17.4},
#  {'_id': '1b17c792-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06124',
#   'timeCreated': 1598132432761876.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 14.8},
#  {'_id': '1b17a56e-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '06124',
#   'timeCreated': 1598132432760980.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1010.5},
#  {'_id': '1b17a33e-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '06124',
#   'timeCreated': 1598132432760927.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1009.6},
#  {'_id': '1b179e34-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06124',
#   'timeCreated': 1598132432760815.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 85.0},
#  {'_id': '1b177fa8-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'weather',
#   'stationId': '06124',
#   'timeCreated': 1598132432760015.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 100.0},
#  {'_id': '1b177ada-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'visibility',
#   'stationId': '06124',
#   'timeCreated': 1598132432759910.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 18000.0},
#  {'_id': '1b176734-e4c0-11ea-9628-b6de4a65a09e',
#   'parameterId': 'visib_mean_last10min',
#   'stationId': '06124',
#   'timeCreated': 1598132432759413.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 18900.0},
#  {'_id': '19e6ad48-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06074',
#   'timeCreated': 1598132430762333.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 3.3},
#  {'_id': '19e6aad2-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06074',
#   'timeCreated': 1598132430762273.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 5.1},
#  {'_id': '19e6a654-e4c0-11ea-8135-46818c941500',
#   'parameterId': 'precip_dur_past10min',
#   'stationId': '06074',
#   'timeCreated': 1598132430762196.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '19e6a730-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06074',
#   'timeCreated': 1598132430762186.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 206.0},
#  {'_id': '19e6a24e-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06074',
#   'timeCreated': 1598132430762075.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 15.5},
#  {'_id': '19e69bb4-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06074',
#   'timeCreated': 1598132430761910.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 13.2},
#  {'_id': '19e69092-e4c0-11ea-9628-b6de4a65a09e',
#   'parameterId': 'visib_mean_last10min',
#   'stationId': '06074',
#   'timeCreated': 1598132430761619.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 24900.0},
#  {'_id': '19e67094-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '06074',
#   'timeCreated': 1598132430760777.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1008.3},
#  {'_id': '19e66e96-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '06074',
#   'timeCreated': 1598132430760729.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1001.8},
#  {'_id': '19e66a86-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'precip_past10min',
#   'stationId': '06074',
#   'timeCreated': 1598132430760628.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '19e66496-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06074',
#   'timeCreated': 1598132430760489.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 86.0},
#  {'_id': '19e64dd0-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'visibility',
#   'stationId': '06074',
#   'timeCreated': 1598132430759889.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 24000.0},
#  {'_id': '19e64830-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'cloud_cover',
#   'stationId': '06074',
#   'timeCreated': 1598132430759781.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '194d9400-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06088',
#   'timeCreated': 1598132429758986.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 18.5},
#  {'_id': '194d8fc8-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06088',
#   'timeCreated': 1598132429758896.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 14.1},
#  {'_id': '194d7948-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'precip_past10min',
#   'stationId': '06088',
#   'timeCreated': 1598132429758303.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '194d7394-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06088',
#   'timeCreated': 1598132429758186.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 76.0},
#  {'_id': '1868e26a-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06132',
#   'timeCreated': 1598132428260215.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 17.0},
#  {'_id': '1868e0da-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06132',
#   'timeCreated': 1598132428260177.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 14.3},
#  {'_id': '1868de96-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'sun_last10min_glob',
#   'stationId': '06132',
#   'timeCreated': 1598132428260128.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '1868d838-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'radia_glob',
#   'stationId': '06132',
#   'timeCreated': 1598132428259986.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '18689760-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06132',
#   'timeCreated': 1598132428258341.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 84.0},
#  {'_id': '16ebceac-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '06193',
#   'timeCreated': 1598132425762788.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1010.8},
#  {'_id': '16ebccfe-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '06193',
#   'timeCreated': 1598132425762746.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1009.7},
#  {'_id': '16ebcb0a-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'precip_past10min',
#   'stationId': '06193',
#   'timeCreated': 1598132425762699.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '16ebc5d8-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06193',
#   'timeCreated': 1598132425762595.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 75.0},
#  {'_id': '16ebb3ea-e4c0-11ea-9628-b6de4a65a09e',
#   'parameterId': 'visib_mean_last10min',
#   'stationId': '06193',
#   'timeCreated': 1598132425762127.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 26600.0},
#  {'_id': '16ebb17e-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'visibility',
#   'stationId': '06193',
#   'timeCreated': 1598132425762051.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 26000.0},
#  {'_id': '16ebacce-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'cloud_height',
#   'stationId': '06193',
#   'timeCreated': 1598132425761930.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 2600.0},
#  {'_id': '16eba6de-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'cloud_cover',
#   'stationId': '06193',
#   'timeCreated': 1598132425761807.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 10.0},
#  {'_id': '16eb98ce-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06193',
#   'timeCreated': 1598132425761410.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 11.0},
#  {'_id': '16eb9716-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06193',
#   'timeCreated': 1598132425761366.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 12.9},
#  {'_id': '16eb9540-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06193',
#   'timeCreated': 1598132425761319.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 248.0},
#  {'_id': '16eb9342-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06193',
#   'timeCreated': 1598132425761269.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 20.3},
#  {'_id': '16eb9162-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06193',
#   'timeCreated': 1598132425761221.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 15.7},
#  {'_id': '16eb8f28-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'sun_last10min_glob',
#   'stationId': '06193',
#   'timeCreated': 1598132425761167.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '16eb89ba-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'radia_glob',
#   'stationId': '06193',
#   'timeCreated': 1598132425761060.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '1653224c-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'visibility',
#   'stationId': '06159',
#   'timeCreated': 1598132424762274.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 22000.0},
#  {'_id': '1652f8d0-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06159',
#   'timeCreated': 1598132424761168.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 10.3},
#  {'_id': '1652f6b4-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06159',
#   'timeCreated': 1598132424761118.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 12.3},
#  {'_id': '1652f402-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06159',
#   'timeCreated': 1598132424761046.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 229.0},
#  {'_id': '1652f1fa-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06159',
#   'timeCreated': 1598132424760995.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 18.3},
#  {'_id': '1652ede0-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06159',
#   'timeCreated': 1598132424760908.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 15.4},
#  {'_id': '1652ca5e-e4c0-11ea-9628-b6de4a65a09e',
#   'parameterId': 'visib_mean_last10min',
#   'stationId': '06159',
#   'timeCreated': 1598132424759999.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 22200.0},
#  {'_id': '1652934a-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '06159',
#   'timeCreated': 1598132424758570.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1009.0},
#  {'_id': '1652908e-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '06159',
#   'timeCreated': 1598132424758501.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1007.1},
#  {'_id': '16528e40-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'precip_past10min',
#   'stationId': '06159',
#   'timeCreated': 1598132424758442.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '165288d2-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06159',
#   'timeCreated': 1598132424758329.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 83.0},
#  {'_id': '15bf9b9e-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06147',
#   'timeCreated': 1598132423795401.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 5.8},
#  {'_id': '15bf9a18-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06147',
#   'timeCreated': 1598132423795363.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 7.3},
#  {'_id': '15bf9842-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06147',
#   'timeCreated': 1598132423795316.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 232.0},
#  {'_id': '15bf9612-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06147',
#   'timeCreated': 1598132423795265.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 18.9},
#  {'_id': '15bf9270-e4c0-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06147',
#   'timeCreated': 1598132423795183.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 15.1},
#  {'_id': '15bee91a-e4c0-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'visibility',
#   'stationId': '06147',
#   'timeCreated': 1598132423790846.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 35000.0},
#  {'_id': '15bedcb8-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '06147',
#   'timeCreated': 1598132423790518.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1011.0},
#  {'_id': '15bedb0a-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '06147',
#   'timeCreated': 1598132423790472.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 1010.5},
#  {'_id': '15bed8f8-e4c0-11ea-8135-46818c941500',
#   'parameterId': 'precip_dur_past10min',
#   'stationId': '06147',
#   'timeCreated': 1598132423790435.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '15bed902-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'precip_past10min',
#   'stationId': '06147',
#   'timeCreated': 1598132423790423.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 0.0},
#  {'_id': '15bed51a-e4c0-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06147',
#   'timeCreated': 1598132423790340.0,
#   'timeObserved': 1598132400000000.0,
#   'value': 79.0},
#  {'_id': '15bd22b0-e4c0-11ea-9628-b6de4a65a09e',
# ...
#   'parameterId': 'humidity',
#   'stationId': '06065',
#   'timeCreated': 1598131811264979.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 95.0},
#  {'_id': 'a8a670d8-e4be-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06065',
#   'timeCreated': 1598131811262082.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 4.5},
#  {'_id': 'a8a66f34-e4be-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06065',
#   'timeCreated': 1598131811262041.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 6.6},
#  {'_id': 'a8a66d22-e4be-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06065',
#   'timeCreated': 1598131811261991.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 213.0},
#  {'_id': 'a8a66a34-e4be-11ea-895a-167819f21958',
#   'parameterId': 'temp_grass',
#   'stationId': '06065',
#   'timeCreated': 1598131811261916.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 14.5},
#  {'_id': 'a8a66854-e4be-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06065',
#   'timeCreated': 1598131811261866.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 14.4},
#  {'_id': 'a8a66606-e4be-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06065',
#   'timeCreated': 1598131811261812.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 13.7},
#  {'_id': 'a8a66246-e4be-11ea-895a-167819f21958',
#   'parameterId': 'sun_last10min_glob',
#   'stationId': '06065',
#   'timeCreated': 1598131811261726.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 0.0},
#  {'_id': 'a8a65b3e-e4be-11ea-895a-167819f21958',
#   'parameterId': 'radia_glob',
#   'stationId': '06065',
#   'timeCreated': 1598131811261575.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 0.0},
#  {'_id': 'a8a653dc-e4be-11ea-b42a-e22e6bb15505',
#   'parameterId': 'temp_soil',
#   'stationId': '06065',
#   'timeCreated': 1598131811261382.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 18.6},
#  {'_id': 'a8a65396-e4be-11ea-8135-46818c941500',
#   'parameterId': 'precip_dur_past10min',
#   'stationId': '06065',
#   'timeCreated': 1598131811261347.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 4.0},
#  {'_id': 'a8a64c20-e4be-11ea-8135-46818c941500',
#   'parameterId': 'leav_hum_dur_past10min',
#   'stationId': '06065',
#   'timeCreated': 1598131811261178.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 10.0},
#  {'_id': 'a80e9894-e4be-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'precip_past10min',
#   'stationId': '06019',
#   'timeCreated': 1598131810266967.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 0.0},
#  {'_id': 'a80e9092-e4be-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06019',
#   'timeCreated': 1598131810266797.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 93.0},
#  {'_id': 'a80e1d60-e4be-11ea-b42a-e22e6bb15505',
#   'parameterId': 'temp_soil',
#   'stationId': '06019',
#   'timeCreated': 1598131810263840.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 17.6},
#  {'_id': 'a80e07bc-e4be-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06019',
#   'timeCreated': 1598131810263301.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 5.0},
#  {'_id': 'a80e046a-e4be-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06019',
#   'timeCreated': 1598131810263167.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 6.7},
#  {'_id': 'a80dffec-e4be-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06019',
#   'timeCreated': 1598131810263052.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 222.0},
#  {'_id': 'a80dfbe6-e4be-11ea-8135-46818c941500',
#   'parameterId': 'leav_hum_dur_past10min',
#   'stationId': '06019',
#   'timeCreated': 1598131810262978.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 10.0},
#  {'_id': 'a80dfc18-e4be-11ea-895a-167819f21958',
#   'parameterId': 'temp_grass',
#   'stationId': '06019',
#   'timeCreated': 1598131810262953.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 14.5},
#  {'_id': 'a80df858-e4be-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06019',
#   'timeCreated': 1598131810262862.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 14.9},
#  {'_id': 'a80df272-e4be-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06019',
#   'timeCreated': 1598131810262728.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 13.7},
#  {'_id': 'a80de7c8-e4be-11ea-895a-167819f21958',
#   'parameterId': 'sun_last10min_glob',
#   'stationId': '06019',
#   'timeCreated': 1598131810262471.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 0.0},
#  {'_id': 'a80ddd82-e4be-11ea-895a-167819f21958',
#   'parameterId': 'radia_glob',
#   'stationId': '06019',
#   'timeCreated': 1598131810262200.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 0.0},
#  {'_id': 'a775045e-e4be-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '04220',
#   'timeCreated': 1598131809260461.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 1012.2},
#  {'_id': 'a77501de-e4be-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '04220',
#   'timeCreated': 1598131809260396.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 1007.1},
#  {'_id': 'a774ffb8-e4be-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'precip_past10min',
#   'stationId': '04220',
#   'timeCreated': 1598131809260342.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 0.0},
#  {'_id': 'a774fab8-e4be-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '04220',
#   'timeCreated': 1598131809260243.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 88.0},
#  {'_id': 'a774a806-e4be-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '04220',
#   'timeCreated': 1598131809258094.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 2.2},
#  {'_id': 'a774a658-e4be-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '04220',
#   'timeCreated': 1598131809258051.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 3.7},
#  {'_id': 'a774a446-e4be-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '04220',
#   'timeCreated': 1598131809257999.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 55.0},
#  {'_id': 'a774a25c-e4be-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '04220',
#   'timeCreated': 1598131809257951.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 6.8},
#  {'_id': 'a774a090-e4be-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'cloud_cover',
#   'stationId': '04220',
#   'timeCreated': 1598131809257930.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 0.0},
#  {'_id': 'a7749ffa-e4be-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '04220',
#   'timeCreated': 1598131809257898.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 4.9},
#  {'_id': 'a77498c0-e4be-11ea-895a-167819f21958',
#   'parameterId': 'radia_glob',
#   'stationId': '04220',
#   'timeCreated': 1598131809257743.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 180.0},
#  {'_id': 'a6478ee4-e4be-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06183',
#   'timeCreated': 1598131807284816.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 11.1},
#  {'_id': 'a6478d5e-e4be-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06183',
#   'timeCreated': 1598131807284778.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 12.9},
#  {'_id': 'a6478b92-e4be-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06183',
#   'timeCreated': 1598131807284734.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 258.0},
#  {'_id': 'a647884a-e4be-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06183',
#   'timeCreated': 1598131807284650.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 19.5},
#  {'_id': 'a64784bc-e4be-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06183',
#   'timeCreated': 1598131807284572.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 15.5},
#  {'_id': 'a6466050-e4be-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '06183',
#   'timeCreated': 1598131807277073.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 1009.7},
#  {'_id': 'a6465e0c-e4be-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '06183',
#   'timeCreated': 1598131807277021.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 1008.0},
#  {'_id': 'a64659d4-e4be-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06183',
#   'timeCreated': 1598131807276923.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 78.0},
#  {'_id': 'a6464c8c-e4be-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'visibility',
#   'stationId': '06183',
#   'timeCreated': 1598131807276582.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 50000.0},
#  {'_id': 'a645d7b6-e4be-11ea-9628-b6de4a65a09e',
#   'parameterId': 'visib_mean_last10min',
#   'stationId': '06096',
#   'timeCreated': 1598131807273601.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 16600.0},
#  {'_id': 'a64420a6-e4be-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'weather',
#   'stationId': '06096',
#   'timeCreated': 1598131807262340.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 123.0},
#  {'_id': 'a6441dea-e4be-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'visibility',
#   'stationId': '06096',
#   'timeCreated': 1598131807262271.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 16000.0},
#  {'_id': 'a6441a98-e4be-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'cloud_height',
#   'stationId': '06096',
#   'timeCreated': 1598131807262191.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 800.0},
#  {'_id': 'a6441462-e4be-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'cloud_cover',
#   'stationId': '06096',
#   'timeCreated': 1598131807262041.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 40.0},
#  {'_id': 'a643e168-e4be-11ea-9628-b6de4a65a09e',
#   'parameterId': 'visib_mean_last10min',
#   'stationId': '06183',
#   'timeCreated': 1598131807260746.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 50000.0},
#  {'_id': 'a64384de-e4be-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '06096',
#   'timeCreated': 1598131807258347.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 8.6},
#  {'_id': 'a6438312-e4be-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '06096',
#   'timeCreated': 1598131807258301.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 11.5},
#  {'_id': 'a6438132-e4be-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '06096',
#   'timeCreated': 1598131807258252.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 242.0},
#  {'_id': 'a6437f2a-e4be-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06096',
#   'timeCreated': 1598131807258201.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 18.0},
#  {'_id': 'a6437d4a-e4be-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06096',
#   'timeCreated': 1598131807258154.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 14.4},
#  {'_id': 'a6437b1a-e4be-11ea-895a-167819f21958',
#   'parameterId': 'sun_last10min_glob',
#   'stationId': '06096',
#   'timeCreated': 1598131807258100.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 0.0},
#  {'_id': 'a6437a84-e4be-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '06096',
#   'timeCreated': 1598131807258089.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 1008.6},
#  {'_id': 'a6437714-e4be-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '06096',
#   'timeCreated': 1598131807258005.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 1007.5},
#  {'_id': 'a64375de-e4be-11ea-895a-167819f21958',
#   'parameterId': 'radia_glob',
#   'stationId': '06096',
#   'timeCreated': 1598131807257991.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 0.0},
#  {'_id': 'a6436fbc-e4be-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06096',
#   'timeCreated': 1598131807257849.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 79.0},
#  {'_id': 'a5ad55d6-e4be-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06186',
#   'timeCreated': 1598131806274176.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 78.0},
#  {'_id': 'a5aba10a-e4be-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06186',
#   'timeCreated': 1598131806262924.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 18.1},
#  {'_id': 'a5ab9b38-e4be-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06186',
#   'timeCreated': 1598131806262809.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 14.2},
#  {'_id': 'a5152e00-e4be-11ea-895a-167819f21958',
#   'parameterId': 'sun_last10min_glob',
#   'stationId': '06187',
#   'timeCreated': 1598131805276940.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 0.0},
#  {'_id': 'a51528c4-e4be-11ea-895a-167819f21958',
#   'parameterId': 'radia_glob',
#   'stationId': '06187',
#   'timeCreated': 1598131805276826.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 0.0},
#  {'_id': 'a5134aa4-e4be-11ea-9628-b6de4a65a09e',
#   'parameterId': 'visib_mean_last10min',
#   'stationId': '04339',
#   'timeCreated': 1598131805264609.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 50000.0},
#  {'_id': 'a51328b2-e4be-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure_at_sea',
#   'stationId': '04339',
#   'timeCreated': 1598131805263699.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 1012.7},
#  {'_id': 'a5132894-e4be-11ea-895a-167819f21958',
#   'parameterId': 'wind_speed',
#   'stationId': '04339',
#   'timeCreated': 1598131805263689.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 1.3},
#  {'_id': 'a513265a-e4be-11ea-abf8-bea6434b3bf8',
#   'parameterId': 'visibility',
#   'stationId': '04339',
#   'timeCreated': 1598131805263666.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 50000.0},
#  {'_id': 'a51326fa-e4be-11ea-895a-167819f21958',
#   'parameterId': 'wind_max',
#   'stationId': '04339',
#   'timeCreated': 1598131805263648.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 2.1},
#  {'_id': 'a51325ba-e4be-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'pressure',
#   'stationId': '04339',
#   'timeCreated': 1598131805263623.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 1003.8},
#  {'_id': 'a5132560-e4be-11ea-895a-167819f21958',
#   'parameterId': 'wind_dir',
#   'stationId': '04339',
#   'timeCreated': 1598131805263606.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 290.0},
#  {'_id': 'a513239e-e4be-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '04339',
#   'timeCreated': 1598131805263563.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 5.3},
#  {'_id': 'a51321aa-e4be-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '04339',
#   'timeCreated': 1598131805263516.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 1.1},
#  {'_id': 'a5131ea8-e4be-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '04339',
#   'timeCreated': 1598131805263481.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 74.0},
#  {'_id': 'a5131c96-e4be-11ea-895a-167819f21958',
#   'parameterId': 'radia_glob',
#   'stationId': '04339',
#   'timeCreated': 1598131805263413.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 17.0},
#  {'_id': '9d0a24f4-e4be-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'precip_past10min',
#   'stationId': '06051',
#   'timeCreated': 1598131791782843.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 0.0},
#  {'_id': '9d0a22f6-e4be-11ea-895a-167819f21958',
#   'parameterId': 'temp_dry',
#   'stationId': '06051',
#   'timeCreated': 1598131791782792.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 16.1},
#  {'_id': '9d0a20e4-e4be-11ea-b6ca-8e6a186fc6ce',
#   'parameterId': 'humidity',
#   'stationId': '06051',
#   'timeCreated': 1598131791782757.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 90.0},
#  {'_id': '9d0a1eb4-e4be-11ea-895a-167819f21958',
#   'parameterId': 'temp_dew',
#   'stationId': '06051',
#   'timeCreated': 1598131791782703.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 14.4},
#  {'_id': '9d06cf8e-e4be-11ea-8135-46818c941500',
#   'parameterId': 'precip_dur_past10min',
#   'stationId': '06174',
#   'timeCreated': 1598131791761000.0,
#   'timeObserved': 1598131800000000.0,
#   'value': 0.0}]

# %%
#Convert JSON data to pandas dataframe
df = pd.DataFrame(json)
df
# Out:
#                                       _id           parameterId stationId  \
# 0    39ca9624-e4c0-11ea-895a-167819f21958            wind_speed     04320
# 1    39ca9336-e4c0-11ea-895a-167819f21958              wind_max     04320
# 2    39ca8ff8-e4c0-11ea-895a-167819f21958              wind_dir     04320
# 3    39ca8cc4-e4c0-11ea-895a-167819f21958              temp_dry     04320
# 4    39ca8918-e4c0-11ea-895a-167819f21958              temp_dew     04320
# ..                                    ...                   ...       ...
# 995  9d0a24f4-e4be-11ea-b6ca-8e6a186fc6ce      precip_past10min     06051
# 996  9d0a22f6-e4be-11ea-895a-167819f21958              temp_dry     06051
# 997  9d0a20e4-e4be-11ea-b6ca-8e6a186fc6ce              humidity     06051
# 998  9d0a1eb4-e4be-11ea-895a-167819f21958              temp_dew     06051
# 999  9d06cf8e-e4be-11ea-8135-46818c941500  precip_dur_past10min     06174
#
#       timeCreated  timeObserved  value
# 0    1.598132e+15  1.598132e+15    0.4
# 1    1.598132e+15  1.598132e+15    1.1
# 2    1.598132e+15  1.598132e+15  162.0
# 3    1.598132e+15  1.598132e+15    6.3
# 4    1.598132e+15  1.598132e+15    2.5
# ..            ...           ...    ...
# 995  1.598132e+15  1.598132e+15    0.0
# 996  1.598132e+15  1.598132e+15   16.1
# 997  1.598132e+15  1.598132e+15   90.0
# 998  1.598132e+15  1.598132e+15   14.4
# 999  1.598132e+15  1.598132e+15    0.0
#
# [1000 rows x 6 columns]

# %%
#Creating a new time variable with format YYYY-MM-DD HH:MM:SS
df['time'] = pd.to_datetime(df['timeObserved'], unit='us')
df['time']
# Out:
# 0     2020-08-22 21:40:00
# 1     2020-08-22 21:40:00
# 2     2020-08-22 21:40:00
# 3     2020-08-22 21:40:00
# 4     2020-08-22 21:40:00
#               ...
# 995   2020-08-22 21:30:00
# 996   2020-08-22 21:30:00
# 997   2020-08-22 21:30:00
# 998   2020-08-22 21:30:00
# 999   2020-08-22 21:30:00
# Name: time, Length: 1000, dtype: datetime64[ns]

# %%
#We explore the data - here the different observed weather data
#We are interested in temp_mean_past1h according to DMI it is the "Latest hour's mean air temperature measured 2 m over terrain"
parameter_ids = df['parameterId'].unique() 
parameter_ids
# Out:
# array(['wind_speed', 'wind_max', 'wind_dir', 'temp_dry', 'temp_dew',
#        'radia_glob', 'visib_mean_last10min', 'visibility', 'cloud_height',
#        'cloud_cover', 'pressure_at_sea', 'pressure', 'humidity',
#        'precip_past10min', 'temp_grass', 'sun_last10min_glob',
#        'temp_soil', 'leav_hum_dur_past10min', 'weather',
#        'precip_dur_past10min', 'precip_past1min'], dtype=object)

# %%
#Sort relevant data
df2 = df.loc[(df['parameterId']=='temp_mean_past1h')].copy() 
df2.head()
# Out:
# Empty DataFrame
# Columns: [_id, parameterId, stationId, timeCreated, timeObserved, value, time]
# Index: []

# %%
#We explore the data pt. 2 - here the different stations where the weather data is optained
#We need to substract the non danish stations
parameter_ids2 = df['stationId'].unique() 
parameter_ids2
# Out:
# array(['04320', '04272', '06197', '06123', '04250', '06119', '06169',
#        '04271', '06151', '06073', '06072', '06088', '06049', '06074',
#        '06081', '06093', '06149', '06154', '06135', '06147', '06124',
#        '06159', '06132', '06188', '06065', '06193', '04220', '06183',
#        '06019', '06096', '06186', '06187', '04339', '06051', '06082',
#        '06079', '06174', '06058', '06056', '06116', '06041', '06102',
#        '06156', '06031', '06136', '06032', '06138', '06184', '06141',
#        '06126', '06168', '06181', '04390', '06068', '05300'], dtype=object)

# %%
#Request API - station
url = 'https://dmigw.govcloud.dk/metObs/v1/station'
r = requests.get(url ,params={'api-key': api_key})
print(r, r.url)
# Out:
# <Response [200]> https://dmigw.govcloud.dk/metObs/v1/station?api-key=12a4bffe-21d5-4154-96e5-12bf959cc1dd

# %%
#Extract JSON data - station
json_station = r.json()
json_station
# Out:
# [{'_id': '03332ae2-8b67-4f23-92cf-2008a6ceb477',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 55.3286, 'longitude': 8.7433},
#   'name': 'Ribe Renseanlæg',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '25339',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1317427200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1317427200000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '05176251-748b-41a8-87a6-5df83567e128',
#   'country': 'GRL',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 83.7}],
#   'location': {'height': 79.65, 'latitude': 64.1833, 'longitude': -51.7308},
#   'name': 'Nuuk',
#   'owner': 'DMI',
#   'parameterId': ['cloud_height',
#    'humidity_past1h',
#    'humidity',
#    'precip_dur_past1h',
#    'precip_past1h',
#    'precip_dur_past10min',
#    'precip_past10min',
#    'precip_past24h',
#    'pressure',
#    'pressure_at_sea',
#    'sun_last1h_glob',
#    'sun_last10min_glob',
#    'radia_glob_past1h',
#    'radia_glob',
#    'temp_dew',
#    'temp_dry',
#    'temp_min_past1h',
#    'temp_max_past1h',
#    'temp_mean_past1h',
#    'visibility',
#    'visib_mean_last10min',
#    'weather',
#    'wind_dir',
#    'wind_gust_always_past1h',
#    'wind_min',
#    'wind_speed',
#    'wind_speed_past1h',
#    'wind_dir_past1h',
#    'wind_max',
#    'wind_min_past1h',
#    'precip_past1min',
#    'cloud_cover'],
#   'regionId': '4',
#   'stationId': '04250',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 683683200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 683683200000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6070',
#   'wmoStationId': '04250'},
#  {'_id': '08b14664-5cc1-470b-ba8e-a49e84bca83e',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 38, 'latitude': 55.7246, 'longitude': 8.6932},
#   'name': 'Skovlund',
#   'owner': 'DMI',
#   'parameterId': ['precip_past10min',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past1h',
#    'precip_past24h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05320',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1319760000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1319760000000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '0911d008-aba8-48ae-8289-f495dd8333f6',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 7, 'latitude': 56.9564, 'longitude': 10.2232},
#   'name': 'Møllegård Huse',
#   'owner': 'DMI',
#   'parameterId': ['precip_past24h',
#    'precip_past1h',
#    'precip_past10min',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05042',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1414627200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1414627200000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '091c6f08-5de3-453a-892b-314308400d4f',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 55.7161, 'longitude': 12.5622},
#   'name': 'Meteorologisk Institut',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '30215',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1517529600000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1517529600000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '0a102dbe-87a7-4df8-b93b-77f8d535c178',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 44, 'latitude': 54.9316, 'longitude': 9.4116},
#   'name': 'Kliplev',
#   'owner': 'DMI',
#   'parameterId': ['precip_past10min',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past1h',
#    'precip_past24h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05365',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1317168000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1317168000000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '0add6571-664d-4597-9b85-585f7f894962',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 55.2932, 'longitude': 12.4223},
#   'name': 'Møllebjerggård',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '31040',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1317427200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1317427200000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '0e594ce2-e75a-4f8a-aa71-a3e0e68b94bd',
#   'country': 'GRL',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 22}],
#   'location': {'height': 20, 'latitude': 62.5789, 'longitude': -50.4058},
#   'name': 'Ukiiviit',
#   'owner': 'DMI',
#   'parameterId': ['pressure',
#    'pressure_at_sea',
#    'temp_dry',
#    'temp_dew',
#    'wind_dir',
#    'wind_speed'],
#   'regionId': '4',
#   'stationId': '04253',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1282953600000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1282953600000000,
#   'timeValidTo': None,
#   'type': 'GIWS',
#   'wmoCountryCode': '6070',
#   'wmoStationId': '04253'},
#  {'_id': '0ee2706a-0d08-4c80-8cd5-910a8d2d2ac6',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 48, 'latitude': 56.6509, 'longitude': 9.7012},
#   'name': 'Hannerup',
#   'owner': 'DMI',
#   'parameterId': ['precip_past10min',
#    'precip_past1h',
#    'precip_past24h',
#    'precip_dur_past10min',
#    'precip_dur_past1h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05075',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1320192000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1320192000000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '105aab1e-8975-4882-b115-80428b5eb51c',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 54.9872, 'longitude': 8.6652},
#   'name': 'Emmerlev Klev',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '26358',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1317427200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1317427200000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '10915528-887c-417d-8c77-0aaab7a45a46',
#   'country': 'DNK',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 4.89}],
#   'location': {'height': 3.26, 'latitude': 54.5687, 'longitude': 11.9435},
#   'name': 'Gedser',
#   'owner': 'DMI',
#   'parameterId': ['humidity_past1h',
#    'humidity',
#    'precip_past10min',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past1h',
#    'precip_past24h',
#    'pressure',
#    'pressure_at_sea',
#    'radia_glob_past1h',
#    'radia_glob',
#    'sun_last1h_glob',
#    'sun_last10min_glob',
#    'temp_dew',
#    'temp_dry',
#    'temp_min_past1h',
#    'temp_max_past1h',
#    'temp_mean_past1h',
#    'wind_speed_past1h',
#    'wind_gust_always_past1h',
#    'wind_dir',
#    'wind_min',
#    'wind_speed',
#    'wind_dir_past1h',
#    'wind_max',
#    'wind_min_past1h'],
#   'regionId': '6',
#   'stationId': '06149',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1045699200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1045699200000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6080',
#   'wmoStationId': '06149'},
#  {'_id': '118a689d-56a4-46de-8a6d-e02bd981afdf',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 55.8686, 'longitude': 11.6064},
#   'name': 'Kollekolle',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '29020',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1437523200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1437523200000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '1385b9ec-acff-45a0-8670-2756f0c72c45',
#   'country': 'GRL',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 14}],
#   'location': {'height': 12, 'latitude': 65.0131, 'longitude': -52.5286},
#   'name': 'Sioralik',
#   'owner': 'DMI',
#   'parameterId': ['pressure',
#    'pressure_at_sea',
#    'temp_dew',
#    'temp_dry',
#    'wind_speed',
#    'wind_dir'],
#   'regionId': '4',
#   'stationId': '04242',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1254096000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1254096000000000,
#   'timeValidTo': None,
#   'type': 'GIWS',
#   'wmoCountryCode': '6070',
#   'wmoStationId': '04242'},
#  {'_id': '141b75fe-f577-491b-8723-45a3ba9f8fdc',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 55.9571, 'longitude': 8.6196},
#   'name': 'Borris',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '24380',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1324512000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1324512000000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '14c92bef-d475-445b-b53a-f528875eb182',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 57.5705, 'longitude': 10.1073},
#   'name': 'Uggerby',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '20030',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1317427200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1317427200000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '168c79ab-dd80-467e-8da1-6ca315f29ad5',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 15, 'latitude': 56.5032, 'longitude': 8.1465},
#   'name': 'Trans',
#   'owner': 'DMI',
#   'parameterId': ['precip_dur_past10min',
#    'precip_past1h',
#    'precip_past24h',
#    'precip_past10min',
#    'precip_dur_past1h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05296',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1339459200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1339459200000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '18054c00-2cd7-4efd-96b2-38a9d8ed0f05',
#   'country': 'GRL',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 10}],
#   'location': {'height': 8, 'latitude': 80.6494, 'longitude': -13.7119},
#   'name': 'Henrik Krøyer Holme',
#   'owner': 'DMI',
#   'parameterId': ['pressure',
#    'pressure_at_sea',
#    'temp_dry',
#    'temp_dew',
#    'wind_dir',
#    'wind_speed'],
#   'regionId': '4',
#   'stationId': '04313',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1249603200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1249603200000000,
#   'timeValidTo': None,
#   'type': 'GIWS',
#   'wmoCountryCode': '6070',
#   'wmoStationId': '04313'},
#  {'_id': '190dc7d3-361b-4988-8fc5-29c5f774ab8e',
#   'country': 'GRL',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 41}],
#   'location': {'height': 43, 'latitude': 68.7081, 'longitude': -52.8517},
#   'name': 'Aasiaat',
#   'owner': 'DMI',
#   'parameterId': ['cloud_height',
#    'humidity_past1h',
#    'humidity',
#    'precip_past1h',
#    'precip_past24h',
#    'precip_dur_past10min',
#    'precip_dur_past1h',
#    'precip_past10min',
#    'pressure',
#    'pressure_at_sea',
#    'radia_glob_past1h',
#    'radia_glob',
#    'sun_last1h_glob',
#    'sun_last10min_glob',
#    'temp_dew',
#    'temp_dry',
#    'temp_min_past1h',
#    'temp_max_past1h',
#    'temp_mean_past1h',
#    'visib_mean_last10min',
#    'visibility',
#    'weather',
#    'wind_gust_always_past1h',
#    'wind_dir',
#    'wind_min',
#    'wind_speed',
#    'wind_speed_past1h',
#    'wind_dir_past1h',
#    'wind_max',
#    'wind_min_past1h',
#    'precip_past1min',
#    'cloud_cover'],
#   'regionId': '4',
#   'stationId': '04220',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': -378691200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': -378691200000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6070',
#   'wmoStationId': '04220'},
#  {'_id': '19e24932-090d-4867-9642-df9935b87f7f',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 35, 'latitude': 55.6366, 'longitude': 11.4942},
#   'name': 'Mørkøv Syd',
#   'owner': 'DMI',
#   'parameterId': ['precip_dur_past10min',
#    'precip_past10min',
#    'precip_dur_past1h',
#    'precip_past24h',
#    'precip_past1h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05537',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1330560000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1330560000000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '1a09df8a-bced-425c-818e-25ab2f265b91',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 56.951, 'longitude': 8.3769},
#   'name': 'Nørre Vorupør',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '21080',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1317427200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1317427200000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '1a503098-f5af-48dd-8211-8beb0a22a18e',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 13, 'latitude': 54.98, 'longitude': 11.5336},
#   'name': 'Nørreby',
#   'owner': 'DMI',
#   'parameterId': ['precip_past10min',
#    'precip_dur_past10min',
#    'precip_dur_past1h',
#    'precip_past24h',
#    'precip_past1h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05945',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1331596800000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1331596800000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '1b54a785-51e9-4ff8-b941-9413db5ba36c',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 8, 'latitude': 55.0646, 'longitude': 9.68},
#   'name': 'Nørreløkke',
#   'owner': 'DMI',
#   'parameterId': ['precip_past10min',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past1h',
#    'precip_past24h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05375',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1317168000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1317168000000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '20420e36-6dfb-4cae-b8db-2aff069508d2',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 56.3037, 'longitude': 10.6619},
#   'name': 'Tirstrup',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '22189',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1325376000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1325376000000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '21859f92-9fe4-4ea0-b7e2-e2c7dce33c15',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 55.471, 'longitude': 9.0906},
#   'name': 'Askov',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '25270',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1420070400000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1420070400000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '21ce44d4-4795-497f-9305-286dfa6a64aa',
#   'country': 'DNK',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 17.62}],
#   'location': {'height': 13, 'latitude': 55.5575, 'longitude': 8.0828},
#   'name': 'Blåvandshuk Fyr',
#   'owner': 'DMI',
#   'parameterId': ['humidity',
#    'humidity_past1h',
#    'pressure',
#    'pressure_at_sea',
#    'temp_dew',
#    'temp_dry',
#    'temp_min_past1h',
#    'temp_max_past1h',
#    'temp_mean_past1h',
#    'wind_gust_always_past1h',
#    'wind_dir',
#    'wind_min',
#    'wind_speed',
#    'wind_speed_past1h',
#    'wind_dir_past1h',
#    'wind_max',
#    'wind_min_past1h'],
#   'regionId': '6',
#   'stationId': '06081',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 338083200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 338083200000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6080',
#   'wmoStationId': '06081'},
#  {'_id': '21d53907-c55a-44f2-b4cb-8bcb455556a2',
#   'country': 'GRL',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 80}],
#   'location': {'height': 78, 'latitude': 64.7819, 'longitude': -40.3017},
#   'name': 'Ikermit',
#   'owner': 'DMI',
#   'parameterId': ['pressure',
#    'pressure_at_sea',
#    'temp_dew',
#    'temp_dry',
#    'wind_dir',
#    'wind_speed'],
#   'regionId': '4',
#   'stationId': '04373',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1252454400000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1252454400000000,
#   'timeValidTo': None,
#   'type': 'GIWS',
#   'wmoCountryCode': '6070',
#   'wmoStationId': '04373'},
#  {'_id': '21f838c5-2e4b-428c-b544-daf2fead6f96',
#   'country': 'DNK',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 2.7}],
#   'location': {'height': 1.5, 'latitude': 55.1593, 'longitude': 11.1348},
#   'name': 'Omø Fyr',
#   'owner': 'DMI',
#   'parameterId': ['humidity_past1h',
#    'humidity',
#    'pressure_at_sea',
#    'pressure',
#    'temp_dew',
#    'temp_dry',
#    'temp_min_past1h',
#    'temp_max_past1h',
#    'temp_mean_past1h',
#    'wind_max',
#    'wind_min_past1h',
#    'wind_gust_always_past1h',
#    'wind_dir',
#    'wind_min',
#    'wind_speed',
#    'wind_speed_past1h',
#    'wind_dir_past1h'],
#   'regionId': '6',
#   'stationId': '06151',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 727401600000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 727401600000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6080',
#   'wmoStationId': '06151'},
#  {'_id': '22aef020-afdb-4129-b2ab-5cbf7426348a',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 9, 'latitude': 55.7489, 'longitude': 11.3374},
#   'name': 'Havnsø',
#   'owner': 'DMI',
#   'parameterId': ['precip_dur_past1h',
#    'precip_past10min',
#    'precip_past24h',
#    'precip_past1h',
#    'precip_dur_past10min',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05529',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1316649600000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1316649600000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '23a0b02c-fbc7-40b4-b755-70a85a58fea8',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 3, 'latitude': 55.5815, 'longitude': 10.393},
#   'name': 'Tørresø',
#   'owner': 'DMI',
#   'parameterId': ['precip_past1h',
#    'precip_past24h',
#    'precip_past10min',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05406',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1414454400000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1414454400000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '2498d9e5-a828-4a39-ae27-36d0d7334379',
#   'country': 'GRL',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 5.4}],
#   'location': {'height': 3.9, 'latitude': 61.1575, 'longitude': -45.44},
#   'name': 'Narsarsuaq Radiosonde',
#   'owner': 'DMI',
#   'parameterId': ['humidity',
#    'humidity_past1h',
#    'pressure',
#    'pressure_at_sea',
#    'sun_last10min_glob',
#    'radia_glob',
#    'radia_glob_past1h',
#    'sun_last1h_glob',
#    'temp_min_past1h',
#    'temp_dry',
#    'temp_dew',
#    'temp_mean_past1h',
#    'temp_max_past1h',
#    'wind_dir_past1h',
#    'wind_speed_past1h',
#    'wind_speed',
#    'wind_min',
#    'wind_dir',
#    'wind_gust_always_past1h',
#    'wind_min_past1h',
#    'wind_max'],
#   'regionId': '4',
#   'stationId': '04271',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1309996800000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1309996800000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6070',
#   'wmoStationId': '04271'},
#  {'_id': '24d79383-d041-4208-bd47-45c8c9d697fd',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 55.4069, 'longitude': 11.862},
#   'name': 'Mulstrup',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '29243',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1322697600000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1322697600000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '24f678c4-ecd0-40b2-ae1a-4588851e093d',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 26, 'latitude': 56.8334, 'longitude': 8.7296},
#   'name': 'Erslev',
#   'owner': 'DMI',
#   'parameterId': ['precip_past24h',
#    'precip_past10min',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past1h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05105',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1260835200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1260835200000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '2554a502-d37b-4f71-90e7-16f87a1ae75d',
#   'country': 'DNK',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 46.11}],
#   'location': {'height': 44.52, 'latitude': 55.2075, 'longitude': 11.8605},
#   'name': 'Brandelev',
#   'owner': 'DMI',
#   'parameterId': ['cloud_height',
#    'humidity',
#    'humidity_past1h',
#    'precip_dur_past1h',
#    'precip_past10min',
#    'precip_dur_past10min',
#    'precip_past1h',
#    'precip_past24h',
#    'pressure_at_sea',
#    'pressure',
#    'temp_dew',
#    'temp_mean_past1h',
#    'temp_dry',
#    'temp_min_past1h',
#    'temp_max_past1h',
#    'visib_mean_last10min',
#    'visibility',
#    'weather',
#    'wind_max',
#    'wind_min_past1h',
#    'wind_gust_always_past1h',
#    'wind_dir',
#    'wind_min',
#    'wind_speed',
#    'wind_speed_past1h',
#    'wind_dir_past1h',
#    'cloud_cover'],
#   'regionId': '6',
#   'stationId': '06154',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1074643200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1074643200000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6080',
#   'wmoStationId': '06154'},
#  {'_id': '26400fac-7d17-4fe4-9519-9aba8864e42a',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 42, 'latitude': 56.93, 'longitude': 8.6412},
#   'name': 'Silstrup',
#   'owner': 'DMI',
#   'parameterId': ['humidity',
#    'humidity_past1h',
#    'leav_hum_dur_past1h',
#    'leav_hum_dur_past10min',
#    'precip_past10min',
#    'precip_dur_past10min',
#    'precip_past24h',
#    'precip_past1h',
#    'precip_dur_past1h',
#    'radia_glob',
#    'sun_last1h_glob',
#    'sun_last10min_glob',
#    'radia_glob_past1h',
#    'temp_max_past1h',
#    'temp_min_past1h',
#    'temp_dry',
#    'temp_dew',
#    'temp_mean_past1h',
#    'temp_grass_max_past1h',
#    'temp_grass_min_past1h',
#    'temp_grass_mean_past1h',
#    'temp_grass',
#    'temp_soil_mean_past1h',
#    'temp_soil_max_past1h',
#    'temp_soil',
#    'temp_soil_min_past1h',
#    'wind_max',
#    'wind_dir_past1h',
#    'wind_speed_past1h',
#    'wind_speed',
#    'wind_min',
#    'wind_dir',
#    'wind_gust_always_past1h',
#    'wind_min_past1h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '06019',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1016755200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1016755200000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6080',
#   'wmoStationId': '06019'},
#  {'_id': '2734cebf-3073-40d8-a2b3-7bf2b8c20703',
#   'country': 'DNK',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 9.36}],
#   'location': {'height': 7.81, 'latitude': 55.2979, 'longitude': 14.7718},
#   'name': 'Hammer Odde Fyr',
#   'owner': 'DMI',
#   'parameterId': ['cloud_height',
#    'humidity_past1h',
#    'humidity',
#    'precip_dur_past10min',
#    'precip_past1h',
#    'precip_past10min',
#    'precip_past24h',
#    'precip_dur_past1h',
#    'pressure_at_sea',
#    'pressure',
#    'sun_last1h_glob',
#    'sun_last10min_glob',
#    'radia_glob_past1h',
#    'radia_glob',
#    'temp_dry',
#    'temp_dew',
#    'temp_min_past1h',
#    'temp_max_past1h',
#    'temp_mean_past1h',
#    'visib_mean_last10min',
#    'visibility',
#    'weather',
#    'wind_min',
#    'wind_speed',
#    'wind_speed_past1h',
#    'wind_dir_past1h',
#    'wind_max',
#    'wind_min_past1h',
#    'wind_gust_always_past1h',
#    'wind_dir',
#    'precip_past1min',
#    'cloud_cover'],
#   'regionId': '6',
#   'stationId': '06193',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 999129600000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 999129600000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6080',
#   'wmoStationId': '06193'},
#  {'_id': '273fae65-c315-4f00-bae3-dd3fd549bd69',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 85, 'latitude': 56.814, 'longitude': 9.8245},
#   'name': 'Mørkeskov',
#   'owner': 'DMI',
#   'parameterId': ['precip_past10min',
#    'precip_past24h',
#    'precip_past1h',
#    'precip_dur_past10min',
#    'precip_dur_past1h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05065',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1320192000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1320192000000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '280775b1-27f1-4377-b78b-97b694a6eca0',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 56.5062, 'longitude': 10.4403},
#   'name': 'Hevringsholm',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '22080',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1317427200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1317427200000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '28d12825-eb3d-4985-b1ce-527cbdd9a5d1',
#   'country': 'GRL',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 14}],
#   'location': {'height': 12, 'latitude': 67.7817, 'longitude': -32.2842},
#   'name': 'Aputiteeq',
#   'owner': 'DMI',
#   'parameterId': ['pressure_at_sea',
#    'pressure',
#    'temp_dew',
#    'temp_dry',
#    'wind_dir',
#    'wind_speed'],
#   'regionId': '4',
#   'stationId': '04351',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1251936000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1251936000000000,
#   'timeValidTo': None,
#   'type': 'GIWS',
#   'wmoCountryCode': '6070',
#   'wmoStationId': '04351'},
#  {'_id': '290050c4-ae1b-4e40-96bd-9d17c8f1981f',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 8, 'latitude': 57.5705, 'longitude': 10.1074},
#   'name': 'Uggerby',
#   'owner': 'DMI',
#   'parameterId': ['precip_past1h',
#    'precip_past24h',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past10min',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05005',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1260921600000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1260921600000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '2ef18046-9e19-4f58-9068-2f152b56881d',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 7, 'latitude': 55.6861, 'longitude': 12.5439},
#   'name': 'Landbohøjskolen',
#   'owner': 'DMI',
#   'parameterId': ['humidity',
#    'humidity_past1h',
#    'temp_dew',
#    'temp_dry',
#    'temp_min_past1h',
#    'temp_max_past1h',
#    'temp_mean_past1h'],
#   'regionId': '6',
#   'stationId': '06186',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 866160000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 866160000000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6080',
#   'wmoStationId': '06186'},
#  {'_id': '35559cf9-b0e1-4f1b-923a-374b14cb4a3a',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 56.0627, 'longitude': 8.9855},
#   'name': 'Høgild',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '24430',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1324425600000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1324425600000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '35a0f47c-34f1-47df-b40d-7f307705d716',
#   'country': 'DNK',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 3.39}],
#   'location': {'height': 1.65, 'latitude': 55.2444, 'longitude': 9.8882},
#   'name': 'Assens/Torø',
#   'owner': 'DMI',
#   'parameterId': ['pressure_at_sea',
#    'humidity',
#    'humidity_past1h',
#    'pressure',
#    'radia_glob_past1h',
#    'radia_glob',
#    'sun_last1h_glob',
#    'sun_last10min_glob',
#    'temp_dew',
#    'temp_dry',
#    'temp_min_past1h',
#    'temp_max_past1h',
#    'temp_mean_past1h',
#    'visib_mean_last10min',
#    'visibility',
#    'weather',
#    'wind_dir_past1h',
#    'wind_gust_always_past1h',
#    'wind_dir',
#    'wind_min',
#    'wind_speed',
#    'wind_speed_past1h',
#    'wind_max',
#    'wind_min_past1h'],
#   'regionId': '6',
#   'stationId': '06123',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 989280000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 989280000000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6080',
#   'wmoStationId': '06123'},
#  {'_id': '36219748-f386-4b3a-9be4-4e77553c8bb1',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 7, 'latitude': 54.7567, 'longitude': 10.7094},
#   'name': 'Søndenbro',
#   'owner': 'DMI',
#   'parameterId': ['precip_past10min',
#    'precip_past24h',
#    'precip_past1h',
#    'precip_dur_past10min',
#    'precip_dur_past1h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05450',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1260316800000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1260316800000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '37b8075a-a0a6-4f92-bea5-caa6abaee933',
#   'country': 'GRL',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 36}],
#   'location': {'height': 34, 'latitude': 81.6033, 'longitude': -16.6633},
#   'name': 'Station Nord',
#   'owner': 'DMI',
#   'parameterId': ['pressure_at_sea',
#    'pressure',
#    'temp_dry',
#    'temp_dew',
#    'wind_dir',
#    'wind_speed'],
#   'regionId': '4',
#   'stationId': '04312',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1236124800000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1236124800000000,
#   'timeValidTo': None,
#   'type': 'GIWS',
#   'wmoCountryCode': '6070',
#   'wmoStationId': '04312'},
#  {'_id': '388d3a06-d7c3-4d6e-9cde-d310d58f42f4',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 35, 'latitude': 56.1826, 'longitude': 8.4712},
#   'name': 'Grønbjerg',
#   'owner': 'DMI',
#   'parameterId': ['precip_past24h',
#    'precip_past10min',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past1h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05305',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1437350400000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1437350400000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '392c35b8-e99e-42eb-b74a-8693187dfc63',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 55.0561, 'longitude': 8.8326},
#   'name': 'Bredebro',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '26340',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1008288000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1008288000000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '3c06a87a-3bad-47f4-b362-27643d7dafd3',
#   'country': 'GRL',
#   'instrumentParameter': [],
#   'location': {'height': 26, 'latitude': 61.1575, 'longitude': -45.44},
#   'name': 'Narsarsuaq',
#   'owner': 'DMI',
#   'parameterId': ['precip_past24h'],
#   'regionId': None,
#   'stationId': '34270',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1232582400000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1232582400000000,
#   'timeValidTo': None,
#   'type': 'Manual precipitation',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '3dea3cfa-e8fb-4314-8fd9-edc69f635c68',
#   'country': 'DNK',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 22.31}],
#   'location': {'height': 20.74, 'latitude': 55.3955, 'longitude': 12.149},
#   'name': 'Tessebølle',
#   'owner': 'DMI',
#   'parameterId': ['humidity_past1h',
#    'humidity',
#    'leav_hum_dur_past10min',
#    'leav_hum_dur_past1h',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past1h',
#    'precip_past24h',
#    'precip_past10min',
#    'pressure',
#    'pressure_at_sea',
#    'sun_last1h_glob',
#    'sun_last10min_glob',
#    'radia_glob_past1h',
#    'radia_glob',
#    'temp_dry',
#    'temp_min_past1h',
#    'temp_max_past1h',
#    'temp_mean_past1h',
#    'temp_dew',
#    'temp_grass',
#    'temp_grass_max_past1h',
#    'temp_grass_mean_past1h',
#    'temp_grass_min_past1h',
#    'temp_soil_min_past1h',
#    'temp_soil',
#    'temp_soil_max_past1h',
#    'temp_soil_mean_past1h',
#    'visibility',
#    'visib_mean_last10min',
#    'weather',
#    'wind_min',
#    'wind_dir',
#    'wind_gust_always_past1h',
#    'wind_max',
#    'wind_dir_past1h',
#    'wind_speed_past1h',
#    'wind_speed',
#    'wind_min_past1h'],
#   'regionId': '6',
#   'stationId': '06174',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1016064000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1016064000000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6080',
#   'wmoStationId': '06174'},
#  {'_id': '3e0941f7-cdee-4ca9-93e0-f2687da97f48',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 56.6553, 'longitude': 8.5476},
#   'name': 'Semb',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '24043',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1317427200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1317427200000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '3e0999db-e1d1-4f83-9412-7ae5958c4c34',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 6, 'latitude': 55.6858, 'longitude': 12.5768},
#   'name': 'Livgardens Kaserne',
#   'owner': 'DMI',
#   'parameterId': ['precip_past10min',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past1h',
#    'precip_past24h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05735',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1343088000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1343088000000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '40ce8b7c-58c3-4488-acc3-ddb2efc4e37b',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 55.639, 'longitude': 11.4935},
#   'name': 'Mørkøv Syd',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '29194',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1475280000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1475280000000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '419fda57-1c60-4691-b2d0-4596e4a63ddd',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 56.7637, 'longitude': 9.0946},
#   'name': 'Junget',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '21160',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1317427200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1317427200000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '423389c2-b4ff-459f-903f-57a39bd23b73',
#   'country': 'DNK',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 5.85}],
#   'location': {'height': 4.27, 'latitude': 56.0955, 'longitude': 10.5135},
#   'name': 'Sletterhage Fyr',
#   'owner': 'DMI',
#   'parameterId': ['humidity',
#    'humidity_past1h',
#    'pressure',
#    'pressure_at_sea',
#    'temp_dew',
#    'temp_dry',
#    'temp_min_past1h',
#    'temp_max_past1h',
#    'temp_mean_past1h',
#    'wind_max',
#    'wind_gust_always_past1h',
#    'wind_dir',
#    'wind_min',
#    'wind_speed',
#    'wind_speed_past1h',
#    'wind_dir_past1h',
#    'wind_min_past1h'],
#   'regionId': '6',
#   'stationId': '06073',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 989884800000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 989884800000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6080',
#   'wmoStationId': '06073'},
#  {'_id': '42b44840-fe4f-49d6-8312-949320fb340f',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 4, 'latitude': 55.4484, 'longitude': 8.4},
#   'name': 'Nordby',
#   'owner': 'DMI',
#   'parameterId': ['humidity_past1h',
#    'humidity',
#    'precip_past10min',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past1h',
#    'precip_past24h',
#    'temp_max_past1h',
#    'temp_mean_past1h',
#    'temp_dry',
#    'temp_dew',
#    'temp_min_past1h'],
#   'regionId': '6',
#   'stationId': '06088',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1183593600000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1183593600000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6080',
#   'wmoStationId': '06088'},
#  {'_id': '43507ddd-df76-4ea9-abc0-e9ffc3e166d1',
#   'country': 'DNK',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 24.85}],
#   'location': {'height': 23.13, 'latitude': 55.0557, 'longitude': 15.0953},
#   'name': 'Nexø Vest',
#   'owner': 'DMI',
#   'parameterId': ['humidity',
#    'humidity_past1h',
#    'leav_hum_dur_past1h',
#    'leav_hum_dur_past10min',
#    'precip_past10min',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past1h',
#    'precip_past24h',
#    'pressure_at_sea',
#    'pressure',
#    'sun_last10min_glob',
#    'radia_glob',
#    'sun_last1h_glob',
#    'radia_glob_past1h',
#    'temp_mean_past1h',
#    'temp_dew',
#    'temp_dry',
#    'temp_min_past1h',
#    'temp_max_past1h',
#    'temp_grass_min_past1h',
#    'temp_grass_max_past1h',
#    'temp_grass',
#    'temp_grass_mean_past1h',
#    'temp_soil_min_past1h',
#    'temp_soil_mean_past1h',
#    'temp_soil_max_past1h',
#    'temp_soil',
#    'wind_speed',
#    'wind_speed_past1h',
#    'wind_dir_past1h',
#    'wind_max',
#    'wind_min_past1h',
#    'wind_min',
#    'wind_dir',
#    'wind_gust_always_past1h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '06197',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1032393600000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1032393600000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6080',
#   'wmoStationId': '06197'},
#  {'_id': '43af2c74-1a99-4bdc-a15a-7b069f8dbcab',
#   'country': 'DNK',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 23.82}],
#   'location': {'height': 22.09, 'latitude': 55.868, 'longitude': 9.7872},
#   'name': 'Horsens/Bygholm',
#   'owner': 'DMI',
#   'parameterId': ['humidity',
#    'humidity_past1h',
#    'leav_hum_dur_past1h',
#    'leav_hum_dur_past10min',
#    'precip_dur_past10min',
#    'precip_past1h',
#    'precip_past24h',
#    'precip_dur_past1h',
#    'precip_past10min',
#    'pressure_at_sea',
#    'pressure',
#    'sun_last1h_glob',
#    'sun_last10min_glob',
#    'radia_glob_past1h',
#    'radia_glob',
#    'temp_dry',
#    'temp_dew',
#    'temp_min_past1h',
#    'temp_max_past1h',
#    'temp_mean_past1h',
#    'temp_grass_max_past1h',
#    'temp_grass',
#    'temp_grass_min_past1h',
#    'temp_grass_mean_past1h',
#    'temp_soil',
#    'temp_soil_min_past1h',
#    'temp_soil_mean_past1h',
#    'temp_soil_max_past1h',
#    'wind_speed',
#    'wind_speed_past1h',
#    'wind_dir_past1h',
#    'wind_max',
#    'wind_min_past1h',
#    'wind_gust_always_past1h',
#    'wind_dir',
#    'wind_min'],
#   'regionId': '6',
#   'stationId': '06102',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 991008000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 991008000000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6080',
#   'wmoStationId': '06102'},
#  {'_id': '4597e119-8215-414b-ad4f-93869232eec5',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 12, 'latitude': 56.5062, 'longitude': 10.4403},
#   'name': 'Hevringholm',
#   'owner': 'DMI',
#   'parameterId': ['precip_past24h',
#    'precip_past10min',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past1h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05150',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1260748800000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1260748800000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '47531b2e-508a-43ac-8e25-4e29dc686aea',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 54.7926, 'longitude': 11.9101},
#   'name': 'Systofte Skovby Nord',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '31509',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1476662400000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1476662400000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '4769afea-c7df-4f04-8947-10d82d7fbb9c',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 56.184, 'longitude': 8.4863},
#   'name': 'Grønbjerg',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '24171',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1325376000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1325376000000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '479eaf16-6a9e-462a-8254-0acb42f6da1c',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 54.9963, 'longitude': 12.444},
#   'name': 'Borre',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '31259',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1349049600000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1349049600000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': '47ec45c9-c169-4398-9891-67ee4ac053d9',
#   'country': 'DNK',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 89.2}],
#   'location': {'height': 87.59, 'latitude': 56.5604, 'longitude': 10.0929},
#   'name': 'Hald Vest',
#   'owner': 'DMI',
#   'parameterId': ['cloud_height',
#    'humidity_past1h',
#    'humidity',
#    'pressure_at_sea',
#    'pressure',
#    'temp_dry',
#    'temp_min_past1h',
#    'temp_max_past1h',
#    'temp_mean_past1h',
#    'temp_dew',
#    'visibility',
#    'visib_mean_last10min',
#    'weather',
#    'wind_gust_always_past1h',
#    'wind_dir',
#    'wind_min',
#    'wind_speed',
#    'wind_speed_past1h',
#    'wind_dir_past1h',
#    'wind_max',
#    'wind_min_past1h',
#    'cloud_cover'],
#   'regionId': '6',
#   'stationId': '06049',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 942969600000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 942969600000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6080',
#   'wmoStationId': '06049'},
#  {'_id': '4801c9aa-62b2-4599-b5b1-13ba5c9bf9f8',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 8, 'latitude': 55.3041, 'longitude': 10.728},
#   'name': 'Rosilde',
#   'owner': 'DMI',
#   'parameterId': ['precip_past10min',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past1h',
#    'precip_past24h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05469',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1447891200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1447891200000000,
#   'timeValidTo': None,
# ...
#   'wmoStationId': None},
#  {'_id': 'd7a024b8-0a3a-4208-8eae-77a1090dacad',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 21, 'latitude': 56.7637, 'longitude': 9.0945},
#   'name': 'Junget',
#   'owner': 'DMI',
#   'parameterId': ['precip_past24h',
#    'precip_past10min',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past1h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05109',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1279929600000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1279929600000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': 'd8fbcfb4-094b-4fc9-b3b0-7c8e5289d00e',
#   'country': 'DNK',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 15.75}],
#   'location': {'height': 14.16, 'latitude': 55.7435, 'longitude': 10.8694},
#   'name': 'Røsnæs Fyr',
#   'owner': 'DMI',
#   'parameterId': ['humidity_past1h',
#    'humidity',
#    'precip_past1h',
#    'precip_past10min',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past24h',
#    'pressure',
#    'pressure_at_sea',
#    'temp_max_past1h',
#    'temp_mean_past1h',
#    'temp_dew',
#    'temp_dry',
#    'temp_min_past1h',
#    'visibility',
#    'visib_mean_last10min',
#    'weather',
#    'wind_gust_always_past1h',
#    'wind_dir',
#    'wind_min',
#    'wind_speed',
#    'wind_speed_past1h',
#    'wind_dir_past1h',
#    'wind_max',
#    'wind_min_past1h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '06159',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1005782400000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1005782400000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6080',
#   'wmoStationId': '06159'},
#  {'_id': 'dbe57457-0572-4474-ac90-fedc1c15cf1a',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 35, 'latitude': 55.4929, 'longitude': 8.9036},
#   'name': 'Holsted',
#   'owner': 'DMI',
#   'parameterId': ['precip_dur_past10min',
#    'precip_dur_past1h',
#    'precip_past10min',
#    'precip_past1h',
#    'precip_past24h'],
#   'regionId': '6',
#   'stationId': '05343',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1374624000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1374624000000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': 'dc1b6971-0c35-497d-8431-ba116875f90b',
#   'country': 'GRL',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 70.4844, 'longitude': -21.9511},
#   'name': 'Ittoqqortoormiit',
#   'owner': 'DMI',
#   'parameterId': ['precip_past24h'],
#   'regionId': None,
#   'stationId': '34339',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1124236800000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1124236800000000,
#   'timeValidTo': None,
#   'type': 'Manual precipitation',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': 'df1f72a3-a00b-44dd-b653-1d3dcd954671',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 55.4927, 'longitude': 9.8948},
#   'name': 'Båring',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '28110',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1317427200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1317427200000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': 'df88df98-19b4-4ecd-b0f1-c98009f8f5c6',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 56.2763, 'longitude': 9.6213},
#   'name': 'Grønbæk',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '21430',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1317427200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1317427200000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': 'dff23503-39ad-45fb-902a-9c7eb96bb1c5',
#   'country': 'DNK',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 4.72}],
#   'location': {'height': 3, 'latitude': 55.2908, 'longitude': 8.6551},
#   'name': 'Vester Vedsted',
#   'owner': 'DMI',
#   'parameterId': ['humidity_past1h',
#    'humidity',
#    'pressure_at_sea',
#    'pressure',
#    'temp_min_past1h',
#    'temp_max_past1h',
#    'temp_mean_past1h',
#    'temp_dry',
#    'temp_dew',
#    'wind_gust_always_past1h',
#    'wind_dir',
#    'wind_min',
#    'wind_speed',
#    'wind_speed_past1h',
#    'wind_dir_past1h',
#    'wind_max',
#    'wind_min_past1h'],
#   'regionId': '6',
#   'stationId': '06093',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1071100800000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1071100800000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6080',
#   'wmoStationId': '06093'},
#  {'_id': 'e18b2625-6ecb-4cfd-8bf0-3a85711293ca',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 4, 'latitude': 55.0987, 'longitude': 11.8285},
#   'name': 'Køng',
#   'owner': 'DMI',
#   'parameterId': ['precip_past10min',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past1h',
#    'precip_past24h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05935',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1308614400000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1308614400000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': 'e45ec73a-ffd1-44fd-9279-bcd3961ea221',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 55.961, 'longitude': 9.7021},
#   'name': 'Vestbirk',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '23100',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1064448000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1064448000000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': 'e6aea6a8-192d-4af3-b87d-d0af541c9918',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 57.7363, 'longitude': 10.6318},
#   'name': 'Skagen Fyr',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '20000',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 983491200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 983491200000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': 'ea62fe38-a4b1-4842-9adc-78df2f569173',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 25, 'latitude': 56.2763, 'longitude': 9.6213},
#   'name': 'Grønbæk',
#   'owner': 'DMI',
#   'parameterId': ['precip_past10min',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past1h',
#    'precip_past24h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05135',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1263772800000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1263772800000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': 'eda5fa49-54f9-4338-a3ed-ec0b164a6f27',
#   'country': 'GRL',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 28}],
#   'location': {'height': 27, 'latitude': 70.6561, 'longitude': -54.6},
#   'name': 'Nuussuaq',
#   'owner': 'DMI',
#   'parameterId': ['pressure_at_sea',
#    'pressure',
#    'temp_dew',
#    'temp_dry',
#    'wind_speed',
#    'wind_dir'],
#   'regionId': '4',
#   'stationId': '04214',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 401155200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 401155200000000,
#   'timeValidTo': None,
#   'type': 'GIWS',
#   'wmoCountryCode': '6070',
#   'wmoStationId': '04214'},
#  {'_id': 'eea8c535-2448-4047-aa1c-ee8e61483771',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 39, 'latitude': 55.4069, 'longitude': 11.8621},
#   'name': 'Mulstrup',
#   'owner': 'DMI',
#   'parameterId': ['precip_past24h',
#    'precip_past1h',
#    'precip_dur_past10min',
#    'precip_dur_past1h',
#    'precip_past10min',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05499',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1308614400000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1308614400000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': 'f04fdb57-6065-4d42-94bc-97d36e7123a4',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 55.7102, 'longitude': 9.9962},
#   'name': 'Juelsminde',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '23133',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1317427200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1317427200000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': 'f4c0760a-ddc9-48a5-b28b-59612f285004',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 57.0945, 'longitude': 9.5253},
#   'name': 'Brovst',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '20375',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1571788800000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1571788800000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': 'f6ad4ac2-98cc-4293-813d-d891a5b89e0b',
#   'country': 'GRL',
#   'instrumentParameter': [],
#   'location': {'height': 11, 'latitude': 76.7694, 'longitude': -18.6681},
#   'name': 'Danmarkshavn',
#   'owner': 'DMI',
#   'parameterId': ['precip_past24h'],
#   'regionId': None,
#   'stationId': '34320',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1230768000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1230768000000000,
#   'timeValidTo': None,
#   'type': 'Manual precipitation',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': 'f6db146b-b903-4321-80b2-e39e6fdd47b4',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 56.1496, 'longitude': 9.7876},
#   'name': 'Flensted',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '22410',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1317427200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1317427200000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': 'f7cd1393-fe79-4593-ad82-52440437ec7a',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 22, 'latitude': 57.2215, 'longitude': 10.471},
#   'name': 'Voerså Hede',
#   'owner': 'DMI',
#   'parameterId': ['precip_past10min',
#    'precip_past24h',
#    'precip_past1h',
#    'precip_dur_past10min',
#    'precip_dur_past1h',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05035',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1260921600000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1260921600000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': 'f97d6442-e1aa-4ebf-8b56-bef1fd1966f6',
#   'country': 'DNK',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 62.04}],
#   'location': {'height': 60.33, 'latitude': 56.3027, 'longitude': 10.1272},
#   'name': 'Ødum',
#   'owner': 'DMI',
#   'parameterId': ['humidity',
#    'humidity_past1h',
#    'leav_hum_dur_past1h',
#    'leav_hum_dur_past10min',
#    'precip_dur_past1h',
#    'precip_past1h',
#    'precip_past24h',
#    'precip_past10min',
#    'precip_dur_past10min',
#    'pressure_at_sea',
#    'pressure',
#    'sun_last1h_glob',
#    'sun_last10min_glob',
#    'radia_glob_past1h',
#    'radia_glob',
#    'temp_dew',
#    'temp_dry',
#    'temp_min_past1h',
#    'temp_max_past1h',
#    'temp_mean_past1h',
#    'temp_grass_max_past1h',
#    'temp_grass_mean_past1h',
#    'temp_grass',
#    'temp_grass_min_past1h',
#    'temp_soil_max_past1h',
#    'temp_soil',
#    'temp_soil_min_past1h',
#    'temp_soil_mean_past1h',
#    'wind_speed_past1h',
#    'wind_dir_past1h',
#    'wind_max',
#    'wind_min_past1h',
#    'wind_gust_always_past1h',
#    'wind_dir',
#    'wind_min',
#    'wind_speed'],
#   'regionId': '6',
#   'stationId': '06072',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 991008000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 991008000000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6080',
#   'wmoStationId': '06072'},
#  {'_id': 'faeb7e18-2775-486b-bb16-c0e23f83984a',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': 63, 'latitude': 55.4935, 'longitude': 9.8953},
#   'name': 'Båring',
#   'owner': 'DMI',
#   'parameterId': ['precip_past1h',
#    'precip_past24h',
#    'precip_dur_past10min',
#    'precip_dur_past1h',
#    'precip_past10min',
#    'precip_past1min'],
#   'regionId': '6',
#   'stationId': '05400',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1320364800000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1320364800000000,
#   'timeValidTo': None,
#   'type': 'Pluvio',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': 'fe39f145-fdb2-4e9a-9507-d03a4342cbb8',
#   'country': 'DNK',
#   'instrumentParameter': [],
#   'location': {'height': None, 'latitude': 55.723, 'longitude': 8.3327},
#   'name': 'Outrup',
#   'owner': 'DMI',
#   'parameterId': ['snow_depth_man', 'snow_cover_man'],
#   'regionId': None,
#   'stationId': '25045',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1351123200000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1351123200000000,
#   'timeValidTo': None,
#   'type': 'Manual snow',
#   'wmoCountryCode': None,
#   'wmoStationId': None},
#  {'_id': 'fe56c621-2dfd-4dcb-bc3e-53270ccdb70f',
#   'country': 'DNK',
#   'instrumentParameter': [{'parameterId': 'bar_height', 'value': 61.95}],
#   'location': {'height': 60.35, 'latitude': 56.0939, 'longitude': 9.1811},
#   'name': 'Isenvad',
#   'owner': 'DMI',
#   'parameterId': ['humidity',
#    'humidity_past1h',
#    'precip_past24h',
#    'precip_past10min',
#    'precip_dur_past1h',
#    'precip_dur_past10min',
#    'precip_past1h',
#    'pressure_at_sea',
#    'pressure',
#    'sun_last1h_glob',
#    'sun_last10min_glob',
#    'radia_glob_past1h',
#    'radia_glob',
#    'temp_mean_past1h',
#    'temp_dew',
#    'temp_dry',
#    'temp_min_past1h',
#    'temp_max_past1h',
#    'wind_min_past1h',
#    'wind_max',
#    'wind_gust_always_past1h',
#    'wind_dir',
#    'wind_min',
#    'wind_speed',
#    'wind_speed_past1h',
#    'wind_dir_past1h'],
#   'regionId': '6',
#   'stationId': '06068',
#   'status': 'Active',
#   'timeCreated': 1583338006016000,
#   'timeOperationFrom': 1034208000000000,
#   'timeOperationTo': None,
#   'timeUpdated': None,
#   'timeValidFrom': 1034208000000000,
#   'timeValidTo': None,
#   'type': 'Synop',
#   'wmoCountryCode': '6080',
#   'wmoStationId': '06068'}]

# %%
#Convert JSON data to pandas dataframe - station
df_station = pd.DataFrame(json_station)
df_station
# Out:
#                                       _id country  \
# 0    03332ae2-8b67-4f23-92cf-2008a6ceb477     DNK
# 1    05176251-748b-41a8-87a6-5df83567e128     GRL
# 2    08b14664-5cc1-470b-ba8e-a49e84bca83e     DNK
# 3    0911d008-aba8-48ae-8289-f495dd8333f6     DNK
# 4    091c6f08-5de3-453a-892b-314308400d4f     DNK
# ..                                    ...     ...
# 206  f7cd1393-fe79-4593-ad82-52440437ec7a     DNK
# 207  f97d6442-e1aa-4ebf-8b56-bef1fd1966f6     DNK
# 208  faeb7e18-2775-486b-bb16-c0e23f83984a     DNK
# 209  fe39f145-fdb2-4e9a-9507-d03a4342cbb8     DNK
# 210  fe56c621-2dfd-4dcb-bc3e-53270ccdb70f     DNK
#
#                                  instrumentParameter  \
# 0                                                 []
# 1     [{'parameterId': 'bar_height', 'value': 83.7}]
# 2                                                 []
# 3                                                 []
# 4                                                 []
# ..                                               ...
# 206                                               []
# 207  [{'parameterId': 'bar_height', 'value': 62.04}]
# 208                                               []
# 209                                               []
# 210  [{'parameterId': 'bar_height', 'value': 61.95}]
#
#                                               location  \
# 0    {'height': None, 'latitude': 55.3286, 'longitu...
# 1    {'height': 79.65, 'latitude': 64.1833, 'longit...
# 2    {'height': 38, 'latitude': 55.7246, 'longitude...
# 3    {'height': 7, 'latitude': 56.9564, 'longitude'...
# 4    {'height': None, 'latitude': 55.7161, 'longitu...
# ..                                                 ...
# 206  {'height': 22, 'latitude': 57.2215, 'longitude...
# 207  {'height': 60.33, 'latitude': 56.3027, 'longit...
# 208  {'height': 63, 'latitude': 55.4935, 'longitude...
# 209  {'height': None, 'latitude': 55.723, 'longitud...
# 210  {'height': 60.35, 'latitude': 56.0939, 'longit...
#
#                        name owner  \
# 0           Ribe Renseanlæg   DMI
# 1                      Nuuk   DMI
# 2                  Skovlund   DMI
# 3            Møllegård Huse   DMI
# 4    Meteorologisk Institut   DMI
# ..                      ...   ...
# 206             Voerså Hede   DMI
# 207                    Ødum   DMI
# 208                  Båring   DMI
# 209                  Outrup   DMI
# 210                 Isenvad   DMI
#
#                                            parameterId regionId stationId  \
# 0                     [snow_depth_man, snow_cover_man]     None     25339
# 1    [cloud_height, humidity_past1h, humidity, prec...        4     04250
# 2    [precip_past10min, precip_dur_past1h, precip_d...        6     05320
# 3    [precip_past24h, precip_past1h, precip_past10m...        6     05042
# 4                     [snow_depth_man, snow_cover_man]     None     30215
# ..                                                 ...      ...       ...
# 206  [precip_past10min, precip_past24h, precip_past...        6     05035
# 207  [humidity, humidity_past1h, leav_hum_dur_past1...        6     06072
# 208  [precip_past1h, precip_past24h, precip_dur_pas...        6     05400
# 209                   [snow_depth_man, snow_cover_man]     None     25045
# 210  [humidity, humidity_past1h, precip_past24h, pr...        6     06068
#
#      status       timeCreated  timeOperationFrom timeOperationTo timeUpdated  \
# 0    Active  1583338006016000   1317427200000000            None        None
# 1    Active  1583338006016000    683683200000000            None        None
# 2    Active  1583338006016000   1319760000000000            None        None
# 3    Active  1583338006016000   1414627200000000            None        None
# 4    Active  1583338006016000   1517529600000000            None        None
# ..      ...               ...                ...             ...         ...
# 206  Active  1583338006016000   1260921600000000            None        None
# 207  Active  1583338006016000    991008000000000            None        None
# 208  Active  1583338006016000   1320364800000000            None        None
# 209  Active  1583338006016000   1351123200000000            None        None
# 210  Active  1583338006016000   1034208000000000            None        None
#
#         timeValidFrom timeValidTo         type wmoCountryCode wmoStationId
# 0    1317427200000000        None  Manual snow           None         None
# 1     683683200000000        None        Synop           6070        04250
# 2    1319760000000000        None       Pluvio           None         None
# 3    1414627200000000        None       Pluvio           None         None
# 4    1517529600000000        None  Manual snow           None         None
# ..                ...         ...          ...            ...          ...
# 206  1260921600000000        None       Pluvio           None         None
# 207   991008000000000        None        Synop           6080        06072
# 208  1320364800000000        None       Pluvio           None         None
# 209  1351123200000000        None  Manual snow           None         None
# 210  1034208000000000        None        Synop           6080        06068
#
# [211 rows x 19 columns]

# %%
#We explore the station data - here the different countries represented
#We are interested in DNK only
parameter_ids_station = df_station['country'].unique() 
parameter_ids_station
# Out:
# array(['DNK', 'GRL'], dtype=object)

# %%
#Sort relevant data - station
df_station2 =df_station.loc[(df_station['country']=='DNK')].copy()
df_station2
# Out:
#                                       _id country  \
# 0    03332ae2-8b67-4f23-92cf-2008a6ceb477     DNK
# 2    08b14664-5cc1-470b-ba8e-a49e84bca83e     DNK
# 3    0911d008-aba8-48ae-8289-f495dd8333f6     DNK
# 4    091c6f08-5de3-453a-892b-314308400d4f     DNK
# 5    0a102dbe-87a7-4df8-b93b-77f8d535c178     DNK
# ..                                    ...     ...
# 206  f7cd1393-fe79-4593-ad82-52440437ec7a     DNK
# 207  f97d6442-e1aa-4ebf-8b56-bef1fd1966f6     DNK
# 208  faeb7e18-2775-486b-bb16-c0e23f83984a     DNK
# 209  fe39f145-fdb2-4e9a-9507-d03a4342cbb8     DNK
# 210  fe56c621-2dfd-4dcb-bc3e-53270ccdb70f     DNK
#
#                                  instrumentParameter  \
# 0                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# ..                                               ...
# 206                                               []
# 207  [{'parameterId': 'bar_height', 'value': 62.04}]
# 208                                               []
# 209                                               []
# 210  [{'parameterId': 'bar_height', 'value': 61.95}]
#
#                                               location  \
# 0    {'height': None, 'latitude': 55.3286, 'longitu...
# 2    {'height': 38, 'latitude': 55.7246, 'longitude...
# 3    {'height': 7, 'latitude': 56.9564, 'longitude'...
# 4    {'height': None, 'latitude': 55.7161, 'longitu...
# 5    {'height': 44, 'latitude': 54.9316, 'longitude...
# ..                                                 ...
# 206  {'height': 22, 'latitude': 57.2215, 'longitude...
# 207  {'height': 60.33, 'latitude': 56.3027, 'longit...
# 208  {'height': 63, 'latitude': 55.4935, 'longitude...
# 209  {'height': None, 'latitude': 55.723, 'longitud...
# 210  {'height': 60.35, 'latitude': 56.0939, 'longit...
#
#                        name owner  \
# 0           Ribe Renseanlæg   DMI
# 2                  Skovlund   DMI
# 3            Møllegård Huse   DMI
# 4    Meteorologisk Institut   DMI
# 5                   Kliplev   DMI
# ..                      ...   ...
# 206             Voerså Hede   DMI
# 207                    Ødum   DMI
# 208                  Båring   DMI
# 209                  Outrup   DMI
# 210                 Isenvad   DMI
#
#                                            parameterId regionId stationId  \
# 0                     [snow_depth_man, snow_cover_man]     None     25339
# 2    [precip_past10min, precip_dur_past1h, precip_d...        6     05320
# 3    [precip_past24h, precip_past1h, precip_past10m...        6     05042
# 4                     [snow_depth_man, snow_cover_man]     None     30215
# 5    [precip_past10min, precip_dur_past1h, precip_d...        6     05365
# ..                                                 ...      ...       ...
# 206  [precip_past10min, precip_past24h, precip_past...        6     05035
# 207  [humidity, humidity_past1h, leav_hum_dur_past1...        6     06072
# 208  [precip_past1h, precip_past24h, precip_dur_pas...        6     05400
# 209                   [snow_depth_man, snow_cover_man]     None     25045
# 210  [humidity, humidity_past1h, precip_past24h, pr...        6     06068
#
#      status       timeCreated  timeOperationFrom timeOperationTo timeUpdated  \
# 0    Active  1583338006016000   1317427200000000            None        None
# 2    Active  1583338006016000   1319760000000000            None        None
# 3    Active  1583338006016000   1414627200000000            None        None
# 4    Active  1583338006016000   1517529600000000            None        None
# 5    Active  1583338006016000   1317168000000000            None        None
# ..      ...               ...                ...             ...         ...
# 206  Active  1583338006016000   1260921600000000            None        None
# 207  Active  1583338006016000    991008000000000            None        None
# 208  Active  1583338006016000   1320364800000000            None        None
# 209  Active  1583338006016000   1351123200000000            None        None
# 210  Active  1583338006016000   1034208000000000            None        None
#
#         timeValidFrom timeValidTo         type wmoCountryCode wmoStationId
# 0    1317427200000000        None  Manual snow           None         None
# 2    1319760000000000        None       Pluvio           None         None
# 3    1414627200000000        None       Pluvio           None         None
# 4    1517529600000000        None  Manual snow           None         None
# 5    1317168000000000        None       Pluvio           None         None
# ..                ...         ...          ...            ...          ...
# 206  1260921600000000        None       Pluvio           None         None
# 207   991008000000000        None        Synop           6080        06072
# 208  1320364800000000        None       Pluvio           None         None
# 209  1351123200000000        None  Manual snow           None         None
# 210  1034208000000000        None        Synop           6080        06068
#
# [185 rows x 19 columns]

# %%
#Sort station ID
stations=df_station2['stationId']
stations
# Out:
# 0      25339
# 2      05320
# 3      05042
# 4      30215
# 5      05365
#        ...
# 206    05035
# 207    06072
# 208    05400
# 209    25045
# 210    06068
# Name: stationId, Length: 185, dtype: object

# %%
#data period
end_time = pd.datetime.today()
start_time = pd.datetime(2018,8,1)

def funk(dt):
    '''Function converting a datetime objects to a Unix microsecond string'''
    return str(int(pd.to_datetime(dt).value*10**-3))

#Specify query parameters
params = {'api-key' : api_key,
          'from' : datetime_to_unixtime(start_time),
          'to' : datetime_to_unixtime(end_time),
          'parameterId' : 'temp_dry',
          }


r = requests.get(url, params=params) # submit GET request based on url and headers
print(r, r.url) # Print request status and url
# Out:
# <Response [200]> https://dmigw.govcloud.dk/metObs/v1/observation?api-key=12a4bffe-21d5-4154-96e5-12bf959cc1dd&from=1533081600000000&to=1598140208012325&parameterId=temp_dry
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#data period
end_time = pd.datetime.today()
start_time = pd.datetime(2018,8,1)

def datetime_to_unixtime(dt):
    '''Function converting a datetime objects to a Unix microsecond string'''
    return str(int(pd.to_datetime(dt).value*10**-3))

#Specify query parameters
params = {'api-key' : api_key,
          'from' : datetime_to_unixtime(start_time),
          'to' : datetime_to_unixtime(end_time),
          'stationId' : '06188',
          'parameterId' : 'temp_dry',
          'limit' : '1000000000000000',
          }


r = requests.get(url, params=params) # submit GET request based on url and headers
print(r, r.url) # Print request status and url
 #https://dmigw.govcloud.dk/metObs/v1/observation?api-key=12a4bffe-21d5-4154-96e5-12bf959cc1dd
  #      &from=1578614400000000&to=1598139376986196&stationId=06188&limit=1000000000000
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# <Response [200]> https://dmigw.govcloud.dk/metObs/v1/observation?api-key=12a4bffe-21d5-4154-96e5-12bf959cc1dd&from=1533081600000000&to=1598139751140926&stationId=06188&parameterId=temp_dry&limit=1000000000000000

# %%
json = r.json() # Extract JSON object
df = pd.DataFrame(json) # Convert JSON object to a DataFrame

df['time'] = pd.to_datetime(df['timeObserved'], unit='us') # Set the DataFrame index as the observation time

df = df.drop(['_id', 'timeCreated', 'timeObserved'], axis=1) # Delete unused columns

df.index = df['time'] # Set the time as the index
#udvælger temp_dry: Present air temperature measured 2 m over terrain every 10 min
#vejr=df.loc[(df['parameterId'] == 'temp_dry')].copy()
#vejr
#"df2 = df.loc[(df['parameterId']=='temp_dry')].copy() # Set the time as the index

print(df.head()) # Print the first five rows
df
# Out:
#                     parameterId stationId  value                time
# time
# 2020-08-22 21:50:00    temp_dry     06051   16.0 2020-08-22 21:50:00
# 2020-08-22 21:50:00    temp_dry     06174   17.5 2020-08-22 21:50:00
# 2020-08-22 21:50:00    temp_dry     06082   15.8 2020-08-22 21:50:00
# 2020-08-22 21:50:00    temp_dry     06156   16.8 2020-08-22 21:50:00
# 2020-08-22 21:50:00    temp_dry     06058   17.9 2020-08-22 21:50:00
#                     parameterId stationId  value                time
# time
# 2020-08-22 21:50:00    temp_dry     06051   16.0 2020-08-22 21:50:00
# 2020-08-22 21:50:00    temp_dry     06174   17.5 2020-08-22 21:50:00
# 2020-08-22 21:50:00    temp_dry     06082   15.8 2020-08-22 21:50:00
# 2020-08-22 21:50:00    temp_dry     06156   16.8 2020-08-22 21:50:00
# 2020-08-22 21:50:00    temp_dry     06058   17.9 2020-08-22 21:50:00
# ...                         ...       ...    ...                 ...
# 2020-08-22 18:50:00    temp_dry     06168   18.6 2020-08-22 18:50:00
# 2020-08-22 18:50:00    temp_dry     06181   19.3 2020-08-22 18:50:00
# 2020-08-22 18:50:00    temp_dry     06068   16.5 2020-08-22 18:50:00
# 2020-08-22 18:40:00    temp_dry     04320    8.2 2020-08-22 18:40:00
# 2020-08-22 18:40:00    temp_dry     04272    9.1 2020-08-22 18:40:00
#
# [1000 rows x 4 columns]

# %%
import numpy as np
df['time2']=df.time.astype(str).str[:10].copy()
df
# Out:
#                     parameterId stationId  value                time  \
# time
# 2020-08-22 21:50:00    temp_dry     06051   16.0 2020-08-22 21:50:00
# 2020-08-22 21:50:00    temp_dry     06174   17.5 2020-08-22 21:50:00
# 2020-08-22 21:50:00    temp_dry     06082   15.8 2020-08-22 21:50:00
# 2020-08-22 21:50:00    temp_dry     06156   16.8 2020-08-22 21:50:00
# 2020-08-22 21:50:00    temp_dry     06058   17.9 2020-08-22 21:50:00
# ...                         ...       ...    ...                 ...
# 2020-08-22 18:50:00    temp_dry     06168   18.6 2020-08-22 18:50:00
# 2020-08-22 18:50:00    temp_dry     06181   19.3 2020-08-22 18:50:00
# 2020-08-22 18:50:00    temp_dry     06068   16.5 2020-08-22 18:50:00
# 2020-08-22 18:40:00    temp_dry     04320    8.2 2020-08-22 18:40:00
# 2020-08-22 18:40:00    temp_dry     04272    9.1 2020-08-22 18:40:00
#
#                           time2
# time
# 2020-08-22 21:50:00  2020-08-22
# 2020-08-22 21:50:00  2020-08-22
# 2020-08-22 21:50:00  2020-08-22
# 2020-08-22 21:50:00  2020-08-22
# 2020-08-22 21:50:00  2020-08-22
# ...                         ...
# 2020-08-22 18:50:00  2020-08-22
# 2020-08-22 18:50:00  2020-08-22
# 2020-08-22 18:50:00  2020-08-22
# 2020-08-22 18:40:00  2020-08-22
# 2020-08-22 18:40:00  2020-08-22
#
# [1000 rows x 5 columns]

# %%
#Remove the word 'Landsdel' from province#
#Ecommute50.province = commute50.province.astype(str).str[9:] 
A= np.mean(df.value.loc[df['time2']=='2020-08-22'])
B= np.mean(df.value)
#avr_date=np.mean(df.value.loc[df[('time2'=='2020-08-22')])
#df_station2 =df_station.loc[(df_station['country']=='DNK')].copy()
print(A)
print(B)
# Out:
# 15.932100000000007
# 15.932100000000007

# %%
df = df.set_index(['time', 'parameterId','station']).drop_duplicates().unstack(level=-1)['value']

params = ['temp_dry','06156'] # Chosing which parameters to plot

# Generate plot of data
ax = df[params].interpolate().plot(figsize=(12,7), legend=False, fontsize=12, subplots=True)
#ax[0].set_ylabel('Wind speed [m/s]', size=12)
#ax[1].set_ylabel('Humidity [%]', size=12)
ax[0].set_ylabel('Air temperature [$^\circ$C]', size=12)
ax[0].set_xlabel('', size=12)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-272-71458c7458cf> in <module>
# ----> 1 df = df.set_index(['time', 'parameterId','station']).drop_duplicates().unstack(level=-1)['value']
#       2
#       3 params = ['temp_dry','06156'] # Chosing which parameters to plot
#       4
#       5 # Generate plot of data
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['station'] are in the columns"
