# %%
#Packages
from bs4 import BeautifulSoup
import pandas as pd
import requests

#import time
#import re
#from selenium import webdriver
#import selenium
#import scraping_class
#logfile = 'log.csv'## name your log file.
#connector = scraping_class.Connector(logfile)

# %%
#WIKI
corona_url = 'https://en.wikipedia.org/wiki/Template:COVID-19_pandemic_data'
table_id2 ='thetable'
response2 = requests.get(corona_url)
soup2 = BeautifulSoup(response2.text,'html.parser')
corona_table = soup2.find('table', attrs={'id': table_id2})
df2=pd.read_html(str(corona_table))
df2

df2[0]
# Out:
#                                            Location[a]  \
#                                     Unnamed: 0_level_1
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 226                                                NaN
# 227                                                NaN
# 228                                                NaN
# 229  As of 20 August 2020 (UTC) · History of cases ...
# 230  Notes ^ Location: Countries, territories, and ...
#
#                                                         \
#                                               World[e]
# 0                                     United States[f]
# 1                                            Brazil[g]
# 2                                                India
# 3                                            Russia[h]
# 4                                         South Africa
# ..                                                 ...
# 226                                           Anguilla
# 227                                     Sint Eustatius
# 228                                       Tanzania[bd]
# 229  As of 20 August 2020 (UTC) · History of cases ...
# 230  Notes ^ Location: Countries, territories, and ...
#
#                                               Cases[b]  \
#                                             22,427,054
# 0                                              5605858
# 1                                              3460413
# 2                                              2836925
# 3                                               942106
# 4                                               596060
# ..                                                 ...
# 226                                                  3
# 227                                                  2
# 228                                            No data
# 229  As of 20 August 2020 (UTC) · History of cases ...
# 230  Notes ^ Location: Countries, territories, and ...
#
#                                              Deaths[c]  \
#                                                788,015
# 0                                               174963
# 1                                               111189
# 2                                                53866
# 3                                                16099
# 4                                                12423
# ..                                                 ...
# 226                                                  0
# 227                                                  0
# 228                                            No data
# 229  As of 20 August 2020 (UTC) · History of cases ...
# 230  Notes ^ Location: Countries, territories, and ...
#
#                                              Recov.[d]  \
#                                             14,349,473
# 0                                              2852221
# 1                                              2615254
# 2                                              2096664
# 3                                               755513
# 4                                               491441
# ..                                                 ...
# 226                                                  3
# 227                                                  2
# 228                                            No data
# 229  As of 20 August 2020 (UTC) · History of cases ...
# 230  Notes ^ Location: Countries, territories, and ...
#
#                                                   Ref.
#                                                    [2]
# 0                                                  [9]
# 1                                             [13][14]
# 2                                                 [15]
# 3                                                 [16]
# 4                                                 [17]
# ..                                                 ...
# 226                                              [315]
# 227                                              [316]
# 228                                         [318][319]
# 229  As of 20 August 2020 (UTC) · History of cases ...
# 230  Notes ^ Location: Countries, territories, and ...
#
# [231 rows x 6 columns]

# %%
#SSI
url = f'https://www.sst.dk/da/corona/tal-og-overvaagning'
response = connector.get(url,'review_getter')
html = response[0].text
soup = BeautifulSoup(html,'html.parser')
score_text_elem = soup.find_all(class_ ='table-responsive')
#score = re.search("\d+\.\d+",score_text_elem.text).group()
score_text_elem
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0d7d06502f28> in <module>
#       1 #SSI
#       2 url = f'https://www.sst.dk/da/corona/tal-og-overvaagning'
# ----> 3 response = connector.get(url,'review_getter')
#       4 html = response[0].text
#       5 soup = BeautifulSoup(html,'html.parser')
#
# NameError: name 'connector' is not defined

# %%
#John
url = f'https://coronavirus.jhu.edu/map.html'
response = connector.get(url,'review_getter')
html = response[0].text
soup = BeautifulSoup(html,'html.parser')
score_text_elem = soup.find_all(class_ ='widget-body flex-fluid full-width flex-vertical overflow-y-auto overflow-x-hidden')
#score = re.search("\d+\.\d+",score_text_elem.text).group()
score_text_elem
#html
# Out:
# []

# %%
#mere john
url = f'https://coronavirus.jhu.edu/testing/tracker/overview'
response = connector.get(url,'review_getter')
html = response[0].text
soup = BeautifulSoup(html,'html.parser')
score_text_elem = soup.find_all(class_ ='number number--teal')
#score = re.search("\d+\.\d+",score_text_elem.text).group()
score_text_elem
#html
# Out:
# []
